# %% [markdown]
# ## 0. Notebook description

# %% [markdown]
# ## 1. Train the model using the default reward function

# %%
from utils.Training import train_model

config_updates = {
    "env_config": {
        "safe_distance_reward": 0.1,
    }
}

train_model(
    env_name="highway-fast-v0",
    config_updates=config_updates,
    notebook_name='2_Group15_RLProject'
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ...

# %% [markdown]
# ## 2. Evaluate the model

# %%
from utils.evaluation import evaluate_model

# Example usage:
env_name = "highway-fast-v0"
model_path = "models/1_Group15_RLProject/"
tensorboard_log_dir = "logs/tensorboard/1_Group15_RLProject_Evaluation"
total_episodes = 200
log_interval = 10

metrics = evaluate_model(env_name, model_path, tensorboard_log_dir, total_episodes, log_interval)
print("Evaluation Metrics:", metrics)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Evaluation Metrics: {'average_reward': 19.328990127736528, 'total_collisions': 0, 'total_safe_distances': 0, 'total_right_lane_usages': 3009}
