# %% [markdown]
#  ## 0. Notebook description

# %% [markdown]
# This notebook is used to compare the performance of different reinforcement learning algorithms on the highway environment with custom rewards. The algorithms being compared are DQN, PPO, A2C, and HER. Each algorithm will be trained using the same environment configuration to guarantee a fair comparison. The custom rewards are designed to promote safer and more realistic driving behaviours.

# %% [markdown]
# ## 1. Train the model

# %% [markdown]
# ##### Setup the environment and training configurations for the custom reward environment.

# %%
from utils.training import train_model
from utils.evaluation import evaluate_model
from gymnasium import register
import gymnasium

config_updates = {
    "safe_distance_reward": 0.1,
    "left_vehicle_overtaken_reward": -0.5,
    "collision_reward": -4,
    "smooth_driving_reward": 0.3,
}

# Register the custom environment
register(
    id='CustomRewardEnv',
    entry_point='HighwayEnvCustomReward:HighwayEnvFastCustomReward',
)

# %% [markdown]
# ### 1.1. Train the model using DQN

# %% [markdown]
# Deep Q-Network (DQN) is a value-based reinforcement learning algorithm. It approximates the Q-value function, which estimates the expected future rewards for each action in a given state. The agent selects actions based on these Q-values to maximize its cumulative reward. DQN is commonly used in environments with discrete action spaces.

# %%
train_model(
    env=env,
    config_updates=config_updates,
    session_name='2_Group15_RLProject',
    algorithm='DQN'
)

evaluate_model(
    env=env,
    config_updates=config_updates,
    model_path='models/custom_reward_function',
    algorithm='DQN',
    total_episodes=200
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/tensorboard/2_Group15_RLProject_DQN_Training\DQN_6
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 32       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 47       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 32       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 106      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.405    |
# |    n_updates        | 1        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 28       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 165      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.48     |
# |    n_updates        | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 28       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 195      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.435    |
# |    n_updates        | 23       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 27       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 242      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.364    |
# |    n_updates        | 35       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 27       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 285      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.399    |
# |    n_updates        | 46       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.83     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 26       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 358      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.346    |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 25       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 391      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.361    |
# |    n_updates        | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 25       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 427      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.281    |
# |    n_updates        | 81       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 24       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 484      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.271    |
# |    n_updates        | 95       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 24       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 525      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.31     |
# |    n_updates        | 106      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 23       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 556      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.259    |
# |    n_updates        | 113      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 23       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 617      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.241    |
# |    n_updates        | 129      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.686    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 22       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 660      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.215    |
# |    n_updates        | 139      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.648    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 21       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 740      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.165    |
# |    n_updates        | 159      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.617    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 21       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 807      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.116    |
# |    n_updates        | 176      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.595    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 20       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 853      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 20       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 909      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0875   |
# |    n_updates        | 202      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.537    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 19       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 974      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0781   |
# |    n_updates        | 218      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 19       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 1020     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0681   |
# |    n_updates        | 229      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.489    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 19       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 1075     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0562   |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 18       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 1174     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 18       |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 1232     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 282      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.387    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 18       |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 1291     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0494   |
# |    n_updates        | 297      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.366    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 18       |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 1335     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 308      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.333    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 18       |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 1404     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0442   |
# |    n_updates        | 325      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.317    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 17       |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 1437     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 334      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.285    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 17       |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 1506     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.044    |
# |    n_updates        | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.276    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 17       |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 1524     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 355      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.249    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 17       |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 1581     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00778  |
# |    n_updates        | 370      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.228    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 17       |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 1625     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0723   |
# |    n_updates        | 381      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.215    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 17       |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 1653     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 388      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.195    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 17       |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 1695     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 398      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.18     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 17       |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 1726     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 406      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 17       |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 1808     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0422   |
# |    n_updates        | 426      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.129    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 17       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 1833     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0382   |
# |    n_updates        | 433      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.0966   |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 17       |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 1902     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.041    |
# |    n_updates        | 450      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.0718   |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 17       |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 1954     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 463      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 17       |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 2058     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 489      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 16       |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 2138     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 509      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 16       |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 2233     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0525   |
# |    n_updates        | 533      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 16       |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 2326     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0499   |
# |    n_updates        | 556      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 16       |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 2377     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 569      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 16       |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 2412     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 577      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 16       |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 2476     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 593      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 16       |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 2510     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00261  |
# |    n_updates        | 602      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 16       |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 2567     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 616      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 16       |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 2627     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00311  |
# |    n_updates        | 631      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 16       |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 2676     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 643      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 16       |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 2712     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0399   |
# |    n_updates        | 652      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 16       |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 2744     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 660      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 16       |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 2821     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0372   |
# |    n_updates        | 680      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 16       |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 2848     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 686      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 16       |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 2923     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0457   |
# |    n_updates        | 705      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 16       |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 2983     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0329   |
# |    n_updates        | 720      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 16       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 3038     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0398   |
# |    n_updates        | 734      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 16       |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 3132     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 757      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 16       |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 3197     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00335  |
# |    n_updates        | 774      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 16       |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 3269     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0543   |
# |    n_updates        | 792      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 16       |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 3309     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 802      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 16       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 3404     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 825      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 16       |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 3475     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.029    |
# |    n_updates        | 843      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 16       |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 3497     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 849      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 16       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 3556     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 863      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 16       |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 3590     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 872      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 16       |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 3614     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0355   |
# |    n_updates        | 878      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 16       |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 3676     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0359   |
# |    n_updates        | 893      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 16       |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 3712     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 902      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 16       |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 3741     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00416  |
# |    n_updates        | 910      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 16       |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 3780     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00204  |
# |    n_updates        | 919      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 16       |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 3803     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00285  |
# |    n_updates        | 925      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 16       |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 3856     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 938      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 16       |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 3906     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00482  |
# |    n_updates        | 951      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 16       |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 3931     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0395   |
# |    n_updates        | 957      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 16       |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 3992     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 972      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 16       |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 4033     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 983      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 16       |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 4082     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 995      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 16       |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 4202     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0385   |
# |    n_updates        | 1025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 16       |
# |    time_elapsed     | 266      |
# |    total_timesteps  | 4269     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0379   |
# |    n_updates        | 1042     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 16       |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 4367     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0507   |
# |    n_updates        | 1066     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 16       |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 4487     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 1096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 15       |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 4581     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0384   |
# |    n_updates        | 1120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 15       |
# |    time_elapsed     | 289      |
# |    total_timesteps  | 4628     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 1131     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 15       |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 4661     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0397   |
# |    n_updates        | 1140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 15       |
# |    time_elapsed     | 294      |
# |    total_timesteps  | 4701     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 1150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 15       |
# |    time_elapsed     | 297      |
# |    total_timesteps  | 4744     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 1160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 15       |
# |    time_elapsed     | 300      |
# |    total_timesteps  | 4776     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 1168     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 15       |
# |    time_elapsed     | 304      |
# |    total_timesteps  | 4846     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 1186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 15       |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 4926     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 1206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 15       |
# |    time_elapsed     | 312      |
# |    total_timesteps  | 4967     |
# | train/              |          |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 15       |
# |    time_elapsed     | 1148     |
# |    total_timesteps  | 17671    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0361   |
# |    n_updates        | 4392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 15       |
# |    time_elapsed     | 1152     |
# |    total_timesteps  | 17729    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 4407     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 15       |
# |    time_elapsed     | 1157     |
# |    total_timesteps  | 17805    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0788   |
# |    n_updates        | 4426     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.8     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 15       |
# |    time_elapsed     | 1163     |
# |    total_timesteps  | 17895    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0428   |
# |    n_updates        | 4448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 15       |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 17979    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0798   |
# |    n_updates        | 4469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 15       |
# |    time_elapsed     | 1176     |
# |    total_timesteps  | 18090    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0698   |
# |    n_updates        | 4497     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 15       |
# |    time_elapsed     | 1181     |
# |    total_timesteps  | 18164    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 4515     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 15       |
# |    time_elapsed     | 1188     |
# |    total_timesteps  | 18273    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 4543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 15       |
# |    time_elapsed     | 1192     |
# |    total_timesteps  | 18343    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0741   |
# |    n_updates        | 4560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 15       |
# |    time_elapsed     | 1198     |
# |    total_timesteps  | 18431    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0369   |
# |    n_updates        | 4582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 15       |
# |    time_elapsed     | 1201     |
# |    total_timesteps  | 18480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0754   |
# |    n_updates        | 4594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 15       |
# |    time_elapsed     | 1206     |
# |    total_timesteps  | 18554    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00795  |
# |    n_updates        | 4613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 15       |
# |    time_elapsed     | 1212     |
# |    total_timesteps  | 18637    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0357   |
# |    n_updates        | 4634     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 15       |
# |    time_elapsed     | 1217     |
# |    total_timesteps  | 18717    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00598  |
# |    n_updates        | 4654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 15       |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 18833    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0772   |
# |    n_updates        | 4683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 15       |
# |    time_elapsed     | 1232     |
# |    total_timesteps  | 18945    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.117    |
# |    n_updates        | 4711     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 15       |
# |    time_elapsed     | 1238     |
# |    total_timesteps  | 19032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00408  |
# |    n_updates        | 4732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 15       |
# |    time_elapsed     | 1245     |
# |    total_timesteps  | 19131    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0425   |
# |    n_updates        | 4757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 15       |
# |    time_elapsed     | 1252     |
# |    total_timesteps  | 19241    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0406   |
# |    n_updates        | 4785     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 15       |
# |    time_elapsed     | 1257     |
# |    total_timesteps  | 19311    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.157    |
# |    n_updates        | 4802     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 15       |
# |    time_elapsed     | 1262     |
# |    total_timesteps  | 19388    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 4821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 15       |
# |    time_elapsed     | 1268     |
# |    total_timesteps  | 19481    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0709   |
# |    n_updates        | 4845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 15       |
# |    time_elapsed     | 1271     |
# |    total_timesteps  | 19538    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00693  |
# |    n_updates        | 4859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.8     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 15       |
# |    time_elapsed     | 1276     |
# |    total_timesteps  | 19611    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0376   |
# |    n_updates        | 4877     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.7     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 15       |
# |    time_elapsed     | 1281     |
# |    total_timesteps  | 19686    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0444   |
# |    n_updates        | 4896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 15       |
# |    time_elapsed     | 1287     |
# |    total_timesteps  | 19777    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0726   |
# |    n_updates        | 4919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 15       |
# |    time_elapsed     | 1293     |
# |    total_timesteps  | 19861    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0445   |
# |    n_updates        | 4940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 15       |
# |    time_elapsed     | 1297     |
# |    total_timesteps  | 19926    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0823   |
# |    n_updates        | 4956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 15       |
# |    time_elapsed     | 1301     |
# |    total_timesteps  | 19980    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0424   |
# |    n_updates        | 4969     |
# ----------------------------------
# Model saved to ./models/2_Group15_RLProject
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}

# %% [markdown]
# ### 1.2. Train the model using PPO

# %% [markdown]
# Proximal Policy Optimization (PPO) is a policy-based reinforcement learning algorithm. It optimises the policy directly by using a surrogate objective function that prevents large updates to the policy, thus allowing stable and reliable learning. PPO is commonly used in environments with continuous action spaces.

# %%
train_model(
    env=env,
    config_updates=config_updates,
    session_name='2_Group15_RLProject',
    algorithm='PPO'
)

evaluate_model(
    env=env,
    config_updates=config_updates,
    model_path='models/custom_reward_function',
    algorithm='PPO',
    total_episodes=200
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/tensorboard/2_Group15_RLProject_PPO_Training\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.6     |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    fps             | 15       |
# |    iterations      | 1        |
# |    time_elapsed    | 128      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.8        |
# |    ep_rew_mean          | 14          |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 2           |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014166875 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.0031      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.61        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0229     |
# |    value_loss           | 15.6        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_model(
#       2     env=env,
#       3     config_updates=config_updates,
#       4     session_name='2_Group15_RLProject',
#       5     algorithm='PPO'
#       6 )
#       8 evaluate_model(
#       9     env=env,
#      10     config_updates=config_updates,
#    (...)
#      13     total_episodes=200
#      14 )
#
# File ~\PycharmProjects\rl-project\rl-project\utils\training.py:70, in train_model(env, config_updates, save_path, model_save_path, total_timesteps, session_name, algorithm, policy, algorithm_kwargs)
#      61 model = AlgorithmClass(
#      62     policy,
#      63     env,
#    (...)
#      66     **algorithm_kwargs
#      67 )
#      69 # Train the model
# ---> 70 model.learn(total_timesteps=total_timesteps, callback=checkpoint_callback)
#      72 # Save the model
#      73 model.save(f"{model_save_path}{session_name}")
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\stable_baselines3\ppo\ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:218, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     213     else:
#     214         # Otherwise, clip the actions to avoid out of bound error
#     215         # as we are sampling from an unbounded Gaussian distribution
#     216         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 218 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     220 self.num_timesteps += env.num_envs
#     222 # Give access to local variables
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\highway_env\envs\common\abstract.py:240, in AbstractEnv.step(self, action)
#     235     raise NotImplementedError(
#     236         "The road and vehicle must be initialized in the environment implementation"
#     237     )
#     239 self.time += 1 / self.config["policy_frequency"]
# --> 240 self._simulate(action)
#     242 obs = self.observation_type.observe()
#     243 reward = self._reward(action)
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\highway_env\envs\common\abstract.py:271, in AbstractEnv._simulate(self, action)
#     259 if (
#     260     action is not None
#     261     and not self.config["manual_control"]
#    (...)
#     267     == 0
#     268 ):
#     269     self.action_type.act(action)
# --> 271 self.road.act()
#     272 self.road.step(1 / self.config["simulation_frequency"])
#     273 self.steps += 1
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\highway_env\road\road.py:464, in Road.act(self)
#     462 """Decide the actions of each entity on the road."""
#     463 for vehicle in self.vehicles:
# --> 464     vehicle.act()
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\highway_env\vehicle\behavior.py:109, in IDMVehicle.act(self, action)
#     107 if self.enable_lane_change:
#     108     self.change_lane_policy()
# --> 109 action["steering"] = self.steering_control(self.target_lane_index)
#     110 action["steering"] = np.clip(
#     111     action["steering"], -self.MAX_STEERING_ANGLE, self.MAX_STEERING_ANGLE
#     112 )
#     114 # Longitudinal: IDM
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\highway_env\vehicle\controller.py:158, in ControlledVehicle.steering_control(self, target_lane_index)
#     146 """
#     147 Steer the vehicle to follow the center of an given lane.
#     148
#    (...)
#     155 :return: a steering wheel angle command [rad]
#     156 """
#     157 target_lane = self.road.network.get_lane(target_lane_index)
# --> 158 lane_coords = target_lane.local_coordinates(self.position)
#     159 lane_next_coords = lane_coords[0] + self.speed * self.TAU_PURSUIT
#     160 lane_future_heading = target_lane.heading_at(lane_next_coords)
#
# File ~\PycharmProjects\rl-project\.venv\Lib\site-packages\highway_env\road\lane.py:211, in StraightLane.local_coordinates(self, position)
#     209 def local_coordinates(self, position: np.ndarray) -> tuple[float, float]:
#     210     delta = position - self.start
# --> 211     longitudinal = np.dot(delta, self.direction)
#     212     lateral = np.dot(delta, self.direction_lateral)
#     213     return float(longitudinal), float(lateral)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 1.3. Train the model using A2C

# %% [markdown]
# Advantage Actor-Critic (A2C) is a synchronous, deterministic variant of the Asynchronous Advantage Actor-Critic (A3C) algorithm. It uses both a policy network (actor) and a value network (critic) to learn the optimal policy and value function simultaneously. The advantage function helps to reduce the variance of the policy updates, leading to more stable learning.

# %%
# Create the environment with the custom parameter
env = gymnasium.make('CustomRewardEnv', render_mode='rgb_array', log_rewards_enabled=False)

train_model(
    env=env,
    config_updates=config_updates,
    session_name='2_Group15_RLProject',
    algorithm='A2C'
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'smooth_driving_reward': 0.3,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/tensorboard/2_Group15_RLProject_A2C_Training\A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 18.4     |
# |    ep_rew_mean        | 16.3     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 100      |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.857   |
# |    explained_variance | 0.0203   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 2.39     |
# |    value_loss         | 6.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.8     |
# |    ep_rew_mean        | 18.6     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 200      |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.706   |
# |    explained_variance | -0.0011  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.536    |
# |    value_loss         | 5.85     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.1     |
# |    ep_rew_mean        | 18.9     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 300      |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.558   |
# |    explained_variance | -0.028   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.402    |
# |    value_loss         | 5.85     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.7     |
# |    ep_rew_mean        | 19.4     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 400      |
# |    time_elapsed       | 158      |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.563   |
# |    explained_variance | 0.00333  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -48.1    |
# |    value_loss         | 525      |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 23.6      |
# |    ep_rew_mean        | 21.2      |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 500       |
# |    time_elapsed       | 199       |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -0.806    |
# |    explained_variance | -0.000206 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 1.29      |
# |    value_loss         | 4.03      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 25.1      |
# |    ep_rew_mean        | 22.7      |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 600       |
# |    time_elapsed       | 238       |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -0.614    |
# |    explained_variance | -0.000864 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 0.734     |
# |    value_loss         | 3.51      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 26.2      |
# |    ep_rew_mean        | 23.7      |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 700       |
# |    time_elapsed       | 278       |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -0.658    |
# |    explained_variance | -2.23e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 0.726     |
# |    value_loss         | 2.93      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 27.2     |
# |    ep_rew_mean        | 24.6     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 800      |
# |    time_elapsed       | 321      |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.715   |
# |    explained_variance | 6.02e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 2.22     |
# |    value_loss         | 2.27     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 28.2      |
# |    ep_rew_mean        | 25.5      |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 900       |
# |    time_elapsed       | 362       |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.401    |
# |    explained_variance | -7.96e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 0.953     |
# |    value_loss         | 0.691     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.5     |
# |    ep_rew_mean        | 26.7     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 1000     |
# |    time_elapsed       | 403      |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.264   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.08     |
# |    value_loss         | 1.61     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.8     |
# |    ep_rew_mean        | 27       |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 1100     |
# |    time_elapsed       | 445      |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.522   |
# |    explained_variance | 1.6e-05  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.886    |
# |    value_loss         | 1.26     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 29.2      |
# |    ep_rew_mean        | 26.4      |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 1200      |
# |    time_elapsed       | 483       |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -0.598    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 0.275     |
# |    value_loss         | 0.965     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 28.7      |
# |    ep_rew_mean        | 26        |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 1300      |
# |    time_elapsed       | 521       |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -0.484    |
# |    explained_variance | -8.98e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.151     |
# |    value_loss         | 0.732     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.7     |
# |    ep_rew_mean        | 26       |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 1400     |
# |    time_elapsed       | 559      |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.419   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.0952   |
# |    value_loss         | 0.478    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 28.4      |
# |    ep_rew_mean        | 25.7      |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 1500      |
# |    time_elapsed       | 597       |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -0.437    |
# |    explained_variance | -7.38e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 0.141     |
# |    value_loss         | 0.304     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 27.6      |
# |    ep_rew_mean        | 25        |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 1600      |
# |    time_elapsed       | 634       |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -0.389    |
# |    explained_variance | -2.48e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 0.0507    |
# |    value_loss         | 0.171     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28       |
# |    ep_rew_mean        | 25.3     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 1700     |
# |    time_elapsed       | 669      |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.217   |
# |    explained_variance | 0.000284 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.0165   |
# |    value_loss         | 0.105    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.2     |
# |    ep_rew_mean        | 25.6     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 1800     |
# |    time_elapsed       | 704      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.00903  |
# |    value_loss         | 0.0133   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.5     |
# |    ep_rew_mean        | 25.9     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 1900     |
# |    time_elapsed       | 740      |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.102   |
# |    explained_variance | 2.03e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -71      |
# |    value_loss         | 3.26e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 28.5     |
# |    ep_rew_mean        | 25.9     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 2000     |
# |    time_elapsed       | 781      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0585  |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.000116 |
# |    value_loss         | 0.000152 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 29.3      |
# |    ep_rew_mean        | 26.7      |
# | time/                 |           |
# |    fps                | 12        |
# |    iterations         | 2100      |
# |    time_elapsed       | 819       |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -0.053    |
# |    explained_variance | 0.00687   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -1.45e-06 |
# |    value_loss         | 2.72e-08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.9     |
# |    ep_rew_mean        | 27.3     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 2200     |
# |    time_elapsed       | 861      |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.0296  |
# |    explained_variance | -0.00266 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 1.05e-05 |
# |    value_loss         | 0.000231 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.8     |
# |    ep_rew_mean        | 27.2     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 2300     |
# |    time_elapsed       | 898      |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.0167  |
# |    explained_variance | -0.00108 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 5.96e-05 |
# |    value_loss         | 0.000812 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.8     |
# |    ep_rew_mean        | 27.3     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 2400     |
# |    time_elapsed       | 932      |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.0191  |
# |    explained_variance | 4.11e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 1.3e-05  |
# |    value_loss         | 2.86e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.9     |
# |    ep_rew_mean        | 27.4     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 2500     |
# |    time_elapsed       | 967      |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.0101  |
# |    explained_variance | -0.0021  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -1.4e-05 |
# |    value_loss         | 0.000149 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.9     |
# |    ep_rew_mean        | 27.4     |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 2600     |
# |    time_elapsed       | 1002     |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.0107  |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 2.29e-05 |
# |    value_loss         | 0.000339 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 29.9      |
# |    ep_rew_mean        | 27.4      |
# | time/                 |           |
# |    fps                | 13        |
# |    iterations         | 2700      |
# |    time_elapsed       | 1036      |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -0.0105   |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -2.57e-05 |
# |    value_loss         | 0.000444  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 29.9     |
# |    ep_rew_mean        | 27.4     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 2800     |
# |    time_elapsed       | 1070     |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.00485 |
# |    explained_variance | 0.00154  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -4.8e-05 |
# |    value_loss         | 0.00767  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 27.4     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 2900     |
# |    time_elapsed       | 1104     |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.0048  |
# |    explained_variance | 0.000329 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 3.93e-07 |
# |    value_loss         | 6.36e-07 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 27.4      |
# | time/                 |           |
# |    fps                | 13        |
# |    iterations         | 3000      |
# |    time_elapsed       | 1138      |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.00348  |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -2.78e-06 |
# |    value_loss         | 6.65e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 27.4     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 3100     |
# |    time_elapsed       | 1172     |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.00343 |
# |    explained_variance | -0.00218 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.0134   |
# |    value_loss         | 0.000311 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 27.4     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 3200     |
# |    time_elapsed       | 1207     |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.00579 |
# |    explained_variance | 7.45e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 8.05e-07 |
# |    value_loss         | 1.73e-06 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 27.5      |
# | time/                 |           |
# |    fps                | 13        |
# |    iterations         | 3300      |
# |    time_elapsed       | 1241      |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -0.00565  |
# |    explained_variance | -0.00247  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -2.43e-06 |
# |    value_loss         | 1.69e-05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 27.5      |
# | time/                 |           |
# |    fps                | 13        |
# |    iterations         | 3400      |
# |    time_elapsed       | 1275      |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -0.00557  |
# |    explained_variance | 0.000467  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -8.48e-05 |
# |    value_loss         | 0.0194    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 27.5     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 3500     |
# |    time_elapsed       | 1309     |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.00555 |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 1.65e-05 |
# |    value_loss         | 0.000804 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 27.5     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 3600     |
# |    time_elapsed       | 1343     |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.00633 |
# |    explained_variance | 0.00252  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.0317  |
# |    value_loss         | 0.000288 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 27.5     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 3700     |
# |    time_elapsed       | 1377     |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.00306 |
# |    explained_variance | -0.00332 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 5.9e-06  |
# |    value_loss         | 0.0004   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 30       |
# |    ep_rew_mean        | 27.4     |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 3800     |
# |    time_elapsed       | 1411     |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.003   |
# |    explained_variance | 1.31e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 2.64e-06 |
# |    value_loss         | 8.42e-05 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 30        |
# |    ep_rew_mean        | 27.4      |
# | time/                 |           |
# |    fps                | 13        |
# |    iterations         | 3900      |
# |    time_elapsed       | 1445      |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -0.00317  |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -6.26e-06 |
# |    value_loss         | 0.00179   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 29.5      |
# |    ep_rew_mean        | 27        |
# | time/                 |           |
# |    fps                | 13        |
# |    iterations         | 4000      |
# |    time_elapsed       | 1478      |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.00293  |
# |    explained_variance | -4.65e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 2.27e-06  |
# |    value_loss         | 0.000943  |
# -------------------------------------
# Model saved to ./models/2_Group15_RLProject

# %%
# Create the environment with the custom parameter
env = gymnasium.make('CustomRewardEnv', render_mode='rgb_array', log_rewards_enabled=True)

evaluate_model(
    env=env,
    config_updates=config_updates,
    model_path='models/2_Group15_RLProject_A2C',
    algorithm='A2C',
    total_episodes=200
)

# %% [markdown]
# ### 1.4. Train the model using ARS

# %% [markdown]
# Augmented Random Search (ARS) is a simple yet effective reinforcement learning algorithm that uses random search to optimize the policy. ARS operates by perturbing the policy parameters with noise, evaluating the performance, and updating the policy based on the results. This method is computationally efficient and easy to implement.

# %%
# Create the environment with the custom parameter
env = gymnasium.make('CustomRewardEnv', render_mode='rgb_array', log_rewards_enabled=False)

train_model(
    env=env,
    config_updates=config_updates,
    session_name='2_Group15_RLProject',
    algorithm='ARS',
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'smooth_driving_reward': 0.3,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/tensorboard/2_Group15_RLProject_ARS_ARS_Training\ARS_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 11.3     |
# |    ep_rew_mean     | 9.85     |
# |    return_std      | 8.5      |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 181      |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 0        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000294 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.6     |
# |    ep_rew_mean     | 16.8     |
# |    return_std      | 9.43     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 479      |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 1        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000265 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15       |
# |    ep_rew_mean     | 13.3     |
# |    return_std      | 10.7     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 719      |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 2        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000234 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.9     |
# |    ep_rew_mean     | 16.1     |
# |    return_std      | 10.6     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 1006     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 3        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000236 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.3     |
# |    ep_rew_mean     | 23       |
# |    return_std      | 8.83     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 1411     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 4        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000283 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.9     |
# |    ep_rew_mean     | 24.6     |
# |    return_std      | 7.9      |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 1842     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 5        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000317 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.194    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 132      |
# |    total_timesteps | 2322     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 6        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0129   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.212    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 159      |
# |    total_timesteps | 2802     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 7        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0118   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.6     |
# |    ep_rew_mean     | 26.9     |
# |    return_std      | 1.74     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 3275     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 8        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.00144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.5     |
# |    ep_rew_mean     | 26.9     |
# |    return_std      | 1.88     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 3747     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 9        |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.00133  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.207    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 237      |
# |    total_timesteps | 4227     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 10       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0121   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.187    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 264      |
# |    total_timesteps | 4707     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 11       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0133   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.227    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 291      |
# |    total_timesteps | 5187     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 12       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.011    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29       |
# |    ep_rew_mean     | 26.6     |
# |    return_std      | 3.86     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 317      |
# |    total_timesteps | 5651     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 13       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000648 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 26.6     |
# |    return_std      | 3.14     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 343      |
# |    total_timesteps | 6118     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 14       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000795 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.23     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 372      |
# |    total_timesteps | 6598     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 15       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0109   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.172    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 401      |
# |    total_timesteps | 7078     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 16       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0145   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.215    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 432      |
# |    total_timesteps | 7558     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 17       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0116   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.229    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 461      |
# |    total_timesteps | 8038     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 18       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0109   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.7     |
# |    ep_rew_mean     | 25.4     |
# |    return_std      | 6.06     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 488      |
# |    total_timesteps | 8481     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 19       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000413 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.1     |
# |    ep_rew_mean     | 26.6     |
# |    return_std      | 3.44     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 516      |
# |    total_timesteps | 8947     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 20       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000726 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.9     |
# |    ep_rew_mean     | 26.3     |
# |    return_std      | 4.11     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 550      |
# |    total_timesteps | 9409     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 21       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000608 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.229    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 580      |
# |    total_timesteps | 9889     |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 22       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0109   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.214    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 609      |
# |    total_timesteps | 10369    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 23       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0117   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.6     |
# |    ep_rew_mean     | 27       |
# |    return_std      | 1.76     |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 638      |
# |    total_timesteps | 10842    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 24       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.00142  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.203    |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 668      |
# |    total_timesteps | 11322    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 25       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0123   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.8     |
# |    ep_rew_mean     | 27.2     |
# |    return_std      | 0.968    |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 706      |
# |    total_timesteps | 11799    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 26       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.00258  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.2     |
# |    ep_rew_mean     | 25.8     |
# |    return_std      | 6.61     |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 734      |
# |    total_timesteps | 12251    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 27       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000378 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.214    |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 760      |
# |    total_timesteps | 12731    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 28       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0117   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.238    |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 786      |
# |    total_timesteps | 13211    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 29       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0105   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.2      |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 811      |
# |    total_timesteps | 13691    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 30       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0125   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.3     |
# |    return_std      | 0.237    |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 837      |
# |    total_timesteps | 14171    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 31       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0105   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.246    |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 864      |
# |    total_timesteps | 14651    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 32       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0102   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.223    |
# | time/              |          |
# |    fps             | 16       |
# |    time_elapsed    | 890      |
# |    total_timesteps | 15131    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 33       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.6     |
# |    ep_rew_mean     | 27       |
# |    return_std      | 1.63     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 916      |
# |    total_timesteps | 15605    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 34       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.00153  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.237    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 941      |
# |    total_timesteps | 16085    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 35       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0105   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.4     |
# |    ep_rew_mean     | 26       |
# |    return_std      | 4.23     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 966      |
# |    total_timesteps | 16540    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 36       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.00059  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.226    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 992      |
# |    total_timesteps | 17020    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 37       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0111   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.208    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 1017     |
# |    total_timesteps | 17500    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 38       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.012    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.4     |
# |    return_std      | 0.214    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 1043     |
# |    total_timesteps | 17980    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 39       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0117   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.216    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 1068     |
# |    total_timesteps | 18460    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 40       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0116   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.214    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 1095     |
# |    total_timesteps | 18940    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 41       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0117   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.193    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 1120     |
# |    total_timesteps | 19420    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 42       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.013    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30       |
# |    ep_rew_mean     | 27.5     |
# |    return_std      | 0.222    |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 1146     |
# |    total_timesteps | 19900    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 43       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.0112   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.8     |
# |    ep_rew_mean     | 26.4     |
# |    return_std      | 4.55     |
# | time/              |          |
# |    fps             | 17       |
# |    time_elapsed    | 1171     |
# |    total_timesteps | 20361    |
# | train/             |          |
# |    delta_std       | 0.05     |
# |    iterations      | 44       |
# |    learning_rate   | 0.02     |
# |    step_size       | 0.000549 |
# ---------------------------------
# Model saved to ./models/2_Group15_RLProject_ARS

# %%
# Create the environment with the custom parameter
env = gymnasium.make('CustomRewardEnv', render_mode='rgb_array', log_rewards_enabled=True)

evaluate_model(
    env=env,
    config_updates=config_updates,
    model_path='models/2_Group15_RLProject_ARS',
    algorithm='ARS',
    total_episodes=200
)

# %% [markdown]
# ### 1.5. Train the model using QR-DQN

# %% [markdown]
# Quantile Regression DQN (QR-DQN) is an extension of the DQN algorithm that estimates the quantiles of the return distribution. By learning the entire distribution of returns, QR-DQN can provide more robust and reliable estimates of the value function. This allows the agent to make better decisions in uncertain environments.

# %%
# Create the environment with the custom parameter
env = gymnasium.make('CustomRewardEnv', render_mode='rgb_array', log_rewards_enabled=False)

train_model(
    env=env,
    config_updates=config_updates,
    session_name='2_Group15_RLProject',
    algorithm='QRDQN',
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'smooth_driving_reward': 0.3,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/tensorboard/2_Group15_RLProject_QRDQN_QRDQN_Training\QRDQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 17       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 61       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 17       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 119      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 40.2     |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 15       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 225      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 41.6     |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 15       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 345      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 40.2     |
# |    n_updates        | 61       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23.2     |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 14       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 465      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 38.9     |
# |    n_updates        | 91       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 24.4     |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 14       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 585      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 37.4     |
# |    n_updates        | 121      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.2     |
# |    ep_rew_mean      | 22.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 14       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 705      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 35.1     |
# |    n_updates        | 151      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25.8     |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 14       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 825      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 30.2     |
# |    n_updates        | 181      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26       |
# |    ep_rew_mean      | 23.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 14       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 936      |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 26.8     |
# |    n_updates        | 208      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.4     |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 14       |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 1056     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 24.1     |
# |    n_updates        | 238      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 26.7     |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 14       |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 1176     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 19.3     |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27       |
# |    ep_rew_mean      | 24.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 14       |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 1296     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 15.1     |
# |    n_updates        | 298      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.2     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 14       |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 1416     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 12.2     |
# |    n_updates        | 328      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.2     |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 14       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 1526     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 10.1     |
# |    n_updates        | 356      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.4     |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 14       |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 1646     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 8.03     |
# |    n_updates        | 386      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.6     |
# |    ep_rew_mean      | 25.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 14       |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 1766     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.51     |
# |    n_updates        | 416      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.7     |
# |    ep_rew_mean      | 25.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 14       |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 1886     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.72     |
# |    n_updates        | 446      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 27.9     |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 14       |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 2006     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.28     |
# |    n_updates        | 476      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28       |
# |    ep_rew_mean      | 25.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 14       |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 2126     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.12     |
# |    n_updates        | 506      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.1     |
# |    ep_rew_mean      | 25.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 14       |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 2246     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.58     |
# |    n_updates        | 536      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.2     |
# |    ep_rew_mean      | 25.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 14       |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 2366     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.8      |
# |    n_updates        | 566      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.2     |
# |    ep_rew_mean      | 25.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 14       |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 2486     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.48     |
# |    n_updates        | 596      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.3     |
# |    ep_rew_mean      | 25.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 14       |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 2606     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.23     |
# |    n_updates        | 626      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.4     |
# |    ep_rew_mean      | 25.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 14       |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 2726     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.43     |
# |    n_updates        | 656      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 28.5     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 14       |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 2846     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.75     |
# |    n_updates        | 686      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.1     |
# |    ep_rew_mean      | 26.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 14       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 2966     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.88     |
# |    n_updates        | 716      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 14       |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 3075     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.06     |
# |    n_updates        | 743      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 14       |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 3195     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.475    |
# |    n_updates        | 773      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 14       |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 3315     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.429    |
# |    n_updates        | 803      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 14       |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 3435     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.419    |
# |    n_updates        | 833      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 14       |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 3555     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.59     |
# |    n_updates        | 863      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 14       |
# |    time_elapsed     | 256      |
# |    total_timesteps  | 3675     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.789    |
# |    n_updates        | 893      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 14       |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 3795     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.394    |
# |    n_updates        | 923      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 14       |
# |    time_elapsed     | 273      |
# |    total_timesteps  | 3915     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.38     |
# |    n_updates        | 953      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 14       |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 4035     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.13     |
# |    n_updates        | 983      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 14       |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 4155     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.556    |
# |    n_updates        | 1013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 14       |
# |    time_elapsed     | 299      |
# |    total_timesteps  | 4275     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.381    |
# |    n_updates        | 1043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 14       |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 4395     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.368    |
# |    n_updates        | 1073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 14       |
# |    time_elapsed     | 316      |
# |    total_timesteps  | 4515     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.515    |
# |    n_updates        | 1103     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 14       |
# |    time_elapsed     | 325      |
# |    total_timesteps  | 4635     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.494    |
# |    n_updates        | 1133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 14       |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 4755     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.366    |
# |    n_updates        | 1163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 14       |
# |    time_elapsed     | 342      |
# |    total_timesteps  | 4875     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.484    |
# |    n_updates        | 1193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 14       |
# |    time_elapsed     | 350      |
# |    total_timesteps  | 4995     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.656    |
# |    n_updates        | 1223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 14       |
# |    time_elapsed     | 359      |
# |    total_timesteps  | 5115     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.742    |
# |    n_updates        | 1253     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 14       |
# |    time_elapsed     | 367      |
# |    total_timesteps  | 5235     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.51     |
# |    n_updates        | 1283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 14       |
# |    time_elapsed     | 376      |
# |    total_timesteps  | 5355     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.359    |
# |    n_updates        | 1313     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 14       |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 5475     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.363    |
# |    n_updates        | 1343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 14       |
# |    time_elapsed     | 391      |
# |    total_timesteps  | 5573     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.361    |
# |    n_updates        | 1368     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 14       |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 5693     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.365    |
# |    n_updates        | 1398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 14       |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 5801     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.565    |
# |    n_updates        | 1425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 14       |
# |    time_elapsed     | 415      |
# |    total_timesteps  | 5921     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.36     |
# |    n_updates        | 1455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 14       |
# |    time_elapsed     | 424      |
# |    total_timesteps  | 6041     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.44     |
# |    n_updates        | 1485     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 14       |
# |    time_elapsed     | 433      |
# |    total_timesteps  | 6161     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.536    |
# |    n_updates        | 1515     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 14       |
# |    time_elapsed     | 441      |
# |    total_timesteps  | 6281     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.363    |
# |    n_updates        | 1545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 14       |
# |    time_elapsed     | 450      |
# |    total_timesteps  | 6401     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.481    |
# |    n_updates        | 1575     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 14       |
# |    time_elapsed     | 458      |
# |    total_timesteps  | 6516     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.36     |
# |    n_updates        | 1603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 14       |
# |    time_elapsed     | 466      |
# |    total_timesteps  | 6636     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.408    |
# |    n_updates        | 1633     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 14       |
# |    time_elapsed     | 475      |
# |    total_timesteps  | 6756     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.363    |
# |    n_updates        | 1663     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 14       |
# |    time_elapsed     | 483      |
# |    total_timesteps  | 6876     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.33     |
# |    n_updates        | 1693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 14       |
# |    time_elapsed     | 492      |
# |    total_timesteps  | 6996     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.404    |
# |    n_updates        | 1723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 14       |
# |    time_elapsed     | 500      |
# |    total_timesteps  | 7116     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.396    |
# |    n_updates        | 1753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 14       |
# |    time_elapsed     | 509      |
# |    total_timesteps  | 7236     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.359    |
# |    n_updates        | 1783     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 14       |
# |    time_elapsed     | 517      |
# |    total_timesteps  | 7356     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.429    |
# |    n_updates        | 1813     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 14       |
# |    time_elapsed     | 526      |
# |    total_timesteps  | 7476     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.402    |
# |    n_updates        | 1843     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 14       |
# |    time_elapsed     | 534      |
# |    total_timesteps  | 7596     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.363    |
# |    n_updates        | 1873     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 14       |
# |    time_elapsed     | 543      |
# |    total_timesteps  | 7716     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.358    |
# |    n_updates        | 1903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 14       |
# |    time_elapsed     | 551      |
# |    total_timesteps  | 7836     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.42     |
# |    n_updates        | 1933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 14       |
# |    time_elapsed     | 560      |
# |    total_timesteps  | 7956     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.39     |
# |    n_updates        | 1963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 14       |
# |    time_elapsed     | 568      |
# |    total_timesteps  | 8076     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.363    |
# |    n_updates        | 1993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 14       |
# |    time_elapsed     | 577      |
# |    total_timesteps  | 8196     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.453    |
# |    n_updates        | 2023     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 14       |
# |    time_elapsed     | 585      |
# |    total_timesteps  | 8316     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.358    |
# |    n_updates        | 2053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 14       |
# |    time_elapsed     | 594      |
# |    total_timesteps  | 8436     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.351    |
# |    n_updates        | 2083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 14       |
# |    time_elapsed     | 602      |
# |    total_timesteps  | 8556     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.374    |
# |    n_updates        | 2113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 14       |
# |    time_elapsed     | 611      |
# |    total_timesteps  | 8676     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.358    |
# |    n_updates        | 2143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 14       |
# |    time_elapsed     | 619      |
# |    total_timesteps  | 8796     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.362    |
# |    n_updates        | 2173     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 14       |
# |    time_elapsed     | 627      |
# |    total_timesteps  | 8905     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.369    |
# |    n_updates        | 2201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.8     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 14       |
# |    time_elapsed     | 636      |
# |    total_timesteps  | 9025     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.12     |
# |    n_updates        | 2231     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 14       |
# |    time_elapsed     | 643      |
# |    total_timesteps  | 9129     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.416    |
# |    n_updates        | 2257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 14       |
# |    time_elapsed     | 651      |
# |    total_timesteps  | 9249     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.353    |
# |    n_updates        | 2287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 14       |
# |    time_elapsed     | 660      |
# |    total_timesteps  | 9369     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.367    |
# |    n_updates        | 2317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 14       |
# |    time_elapsed     | 669      |
# |    total_timesteps  | 9489     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.358    |
# |    n_updates        | 2347     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 14       |
# |    time_elapsed     | 679      |
# |    total_timesteps  | 9609     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.363    |
# |    n_updates        | 2377     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 14       |
# |    time_elapsed     | 689      |
# |    total_timesteps  | 9711     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.364    |
# |    n_updates        | 2402     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 14       |
# |    time_elapsed     | 699      |
# |    total_timesteps  | 9831     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.352    |
# |    n_updates        | 2432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 14       |
# |    time_elapsed     | 709      |
# |    total_timesteps  | 9951     |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.367    |
# |    n_updates        | 2462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 13       |
# |    time_elapsed     | 722      |
# |    total_timesteps  | 10071    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 13.5     |
# |    n_updates        | 2492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 13       |
# |    time_elapsed     | 733      |
# |    total_timesteps  | 10191    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.08     |
# |    n_updates        | 2522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 13       |
# |    time_elapsed     | 745      |
# |    total_timesteps  | 10311    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.277    |
# |    n_updates        | 2552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 13       |
# |    time_elapsed     | 755      |
# |    total_timesteps  | 10431    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.543    |
# |    n_updates        | 2582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 13       |
# |    time_elapsed     | 771      |
# |    total_timesteps  | 10551    |
# ...
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.242    |
# |    n_updates        | 4088     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 12       |
# |    time_elapsed     | 1318     |
# |    total_timesteps  | 16573    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.217    |
# |    n_updates        | 4118     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 12       |
# |    time_elapsed     | 1329     |
# |    total_timesteps  | 16693    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.257    |
# |    n_updates        | 4148     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 12       |
# |    time_elapsed     | 1339     |
# |    total_timesteps  | 16813    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.22     |
# |    n_updates        | 4178     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 12       |
# |    time_elapsed     | 1350     |
# |    total_timesteps  | 16933    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.221    |
# |    n_updates        | 4208     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 12       |
# |    time_elapsed     | 1360     |
# |    total_timesteps  | 17053    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.223    |
# |    n_updates        | 4238     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 12       |
# |    time_elapsed     | 1371     |
# |    total_timesteps  | 17173    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.22     |
# |    n_updates        | 4268     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 12       |
# |    time_elapsed     | 1382     |
# |    total_timesteps  | 17293    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.217    |
# |    n_updates        | 4298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 12       |
# |    time_elapsed     | 1392     |
# |    total_timesteps  | 17413    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.221    |
# |    n_updates        | 4328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 12       |
# |    time_elapsed     | 1403     |
# |    total_timesteps  | 17533    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.216    |
# |    n_updates        | 4358     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 12       |
# |    time_elapsed     | 1413     |
# |    total_timesteps  | 17653    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.22     |
# |    n_updates        | 4388     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 12       |
# |    time_elapsed     | 1423     |
# |    total_timesteps  | 17773    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.02     |
# |    n_updates        | 4418     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 12       |
# |    time_elapsed     | 1433     |
# |    total_timesteps  | 17893    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.223    |
# |    n_updates        | 4448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 12       |
# |    time_elapsed     | 1444     |
# |    total_timesteps  | 18013    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.79     |
# |    n_updates        | 4478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 12       |
# |    time_elapsed     | 1454     |
# |    total_timesteps  | 18133    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.216    |
# |    n_updates        | 4508     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.9     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 12       |
# |    time_elapsed     | 1464     |
# |    total_timesteps  | 18253    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.243    |
# |    n_updates        | 4538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 12       |
# |    time_elapsed     | 1472     |
# |    total_timesteps  | 18343    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.219    |
# |    n_updates        | 4560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.6     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 12       |
# |    time_elapsed     | 1482     |
# |    total_timesteps  | 18463    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.234    |
# |    n_updates        | 4590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 12       |
# |    time_elapsed     | 1492     |
# |    total_timesteps  | 18583    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.217    |
# |    n_updates        | 4620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 12       |
# |    time_elapsed     | 1502     |
# |    total_timesteps  | 18703    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.22     |
# |    n_updates        | 4650     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 12       |
# |    time_elapsed     | 1513     |
# |    total_timesteps  | 18823    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.22     |
# |    n_updates        | 4680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 12       |
# |    time_elapsed     | 1524     |
# |    total_timesteps  | 18943    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.217    |
# |    n_updates        | 4710     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 12       |
# |    time_elapsed     | 1534     |
# |    total_timesteps  | 19063    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.231    |
# |    n_updates        | 4740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 12       |
# |    time_elapsed     | 1544     |
# |    total_timesteps  | 19183    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.218    |
# |    n_updates        | 4770     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 12       |
# |    time_elapsed     | 1555     |
# |    total_timesteps  | 19303    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.223    |
# |    n_updates        | 4800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.7     |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 12       |
# |    time_elapsed     | 1565     |
# |    total_timesteps  | 19423    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.229    |
# |    n_updates        | 4830     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 26.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 12       |
# |    time_elapsed     | 1574     |
# |    total_timesteps  | 19524    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.217    |
# |    n_updates        | 4855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 26.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 12       |
# |    time_elapsed     | 1584     |
# |    total_timesteps  | 19644    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.221    |
# |    n_updates        | 4885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 12       |
# |    time_elapsed     | 1594     |
# |    total_timesteps  | 19764    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.215    |
# |    n_updates        | 4915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.5     |
# |    ep_rew_mean      | 27       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 12       |
# |    time_elapsed     | 1605     |
# |    total_timesteps  | 19884    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.222    |
# |    n_updates        | 4945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 29.4     |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 12       |
# |    time_elapsed     | 1614     |
# |    total_timesteps  | 19992    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.247    |
# |    n_updates        | 4972     |
# ----------------------------------
# Model saved to ./models/2_Group15_RLProject_QRDQN

# %%
# Create the environment with the custom parameter
env = gymnasium.make('CustomRewardEnv', render_mode='rgb_array', log_rewards_enabled=True)

evaluate_model(
    env=env,
    config_updates=config_updates,
    model_path='models/2_Group15_RLProject_QRDQN',
    algorithm='QRDQN',
    total_episodes=200
)

# %% [markdown]
# ### 1.6. Train the model using TRPO

# %% [markdown]
# Trust Region Policy Optimization (TRPO) is a policy-based reinforcement learning algorithm that aims to find the policy that maximizes the expected return while ensuring that the policy update does not deviate too far from the current policy. TRPO uses a constraint on the policy update step to maintain stability and improve sample efficiency.

# %%
# Create the environment with the custom parameter
env = gymnasium.make('CustomRewardEnv', render_mode='rgb_array', log_rewards_enabled=False)

train_model(
    env=env,
    config_updates=config_updates,
    session_name='2_Group15_RLProject',
    algorithm='TRPO',
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'type': 'Kinematics'},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'smooth_driving_reward': 0.3,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/tensorboard/2_Group15_RLProject_TRPO_TRPO_Training\TRPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.9     |
# |    ep_rew_mean     | 9.28     |
# | time/              |          |
# |    fps             | 17       |
# |    iterations      | 1        |
# |    time_elapsed    | 119      |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 13.5     |
# |    ep_rew_mean            | 11.7     |
# | time/                     |          |
# |    fps                    | 17       |
# |    iterations             | 2        |
# |    time_elapsed           | 234      |
# |    total_timesteps        | 4096     |
# | train/                    |          |
# |    explained_variance     | -0.00693 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00825  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1        |
# |    policy_objective       | 0.0272   |
# |    value_loss             | 14.1     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 14.4     |
# |    ep_rew_mean            | 12.5     |
# | time/                     |          |
# |    fps                    | 17       |
# |    iterations             | 3        |
# |    time_elapsed           | 349      |
# |    total_timesteps        | 6144     |
# | train/                    |          |
# |    explained_variance     | 0.0386   |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00873  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 2        |
# |    policy_objective       | 0.0274   |
# |    value_loss             | 24.6     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 17.7     |
# |    ep_rew_mean            | 15.7     |
# | time/                     |          |
# |    fps                    | 17       |
# |    iterations             | 4        |
# |    time_elapsed           | 469      |
# |    total_timesteps        | 8192     |
# | train/                    |          |
# |    explained_variance     | 0.136    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00787  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 3        |
# |    policy_objective       | 0.0301   |
# |    value_loss             | 31.8     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 19.5     |
# |    ep_rew_mean            | 17.4     |
# | time/                     |          |
# |    fps                    | 17       |
# |    iterations             | 5        |
# |    time_elapsed           | 584      |
# |    total_timesteps        | 10240    |
# | train/                    |          |
# |    explained_variance     | 0.154    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00798  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 4        |
# |    policy_objective       | 0.0276   |
# |    value_loss             | 41.5     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 22.6     |
# |    ep_rew_mean            | 20.3     |
# | time/                     |          |
# |    fps                    | 16       |
# |    iterations             | 6        |
# |    time_elapsed           | 729      |
# |    total_timesteps        | 12288    |
# | train/                    |          |
# |    explained_variance     | 0.21     |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0074   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 5        |
# |    policy_objective       | 0.0243   |
# |    value_loss             | 46.2     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 25.5     |
# |    ep_rew_mean            | 23.1     |
# | time/                     |          |
# |    fps                    | 16       |
# |    iterations             | 7        |
# |    time_elapsed           | 860      |
# |    total_timesteps        | 14336    |
# | train/                    |          |
# |    explained_variance     | 0.169    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00776  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 6        |
# |    policy_objective       | 0.0209   |
# |    value_loss             | 54.7     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 26.4     |
# |    ep_rew_mean            | 24       |
# | time/                     |          |
# |    fps                    | 16       |
# |    iterations             | 8        |
# |    time_elapsed           | 994      |
# |    total_timesteps        | 16384    |
# | train/                    |          |
# |    explained_variance     | 0.259    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0068   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 7        |
# |    policy_objective       | 0.0201   |
# |    value_loss             | 44.4     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 24.7     |
# |    ep_rew_mean            | 22.4     |
# | time/                     |          |
# |    fps                    | 16       |
# |    iterations             | 9        |
# |    time_elapsed           | 1123     |
# |    total_timesteps        | 18432    |
# | train/                    |          |
# |    explained_variance     | 0.264    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00634  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 8        |
# |    policy_objective       | 0.0156   |
# |    value_loss             | 60.4     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 26.1     |
# |    ep_rew_mean            | 23.7     |
# | time/                     |          |
# |    fps                    | 16       |
# |    iterations             | 10       |
# |    time_elapsed           | 1266     |
# |    total_timesteps        | 20480    |
# | train/                    |          |
# |    explained_variance     | 0.304    |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00551  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 9        |
# |    policy_objective       | 0.0192   |
# |    value_loss             | 69.3     |
# ----------------------------------------
# Model saved to ./models/2_Group15_RLProject_TRPO

# %%
# Create the environment with the custom parameter
env = gymnasium.make('CustomRewardEnv', render_mode='rgb_array', log_rewards_enabled=True)

evaluate_model(
    env=env,
    config_updates=config_updates,
    model_path='models/2_Group15_RLProject_TRPO',
    algorithm='TRPO',
    total_episodes=200
)

# %% [markdown]
# ### SAC (not compatible)

# %% [markdown]
# Soft Actor-Critic (SAC) is an off-policy actor-critic algorithm that aims to maximize both the expected reward and the entropy of the policy. The entropy term encourages exploration by penalizing certainty, leading to more robust policies. SAC is used in environments with continuous action spaces and is known for its sample efficiency and stability.
