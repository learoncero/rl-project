# %%
from utils.training import train_model
from utils.evaluation import evaluate_model, aggregate_and_normalize_rewards
from gymnasium import register
import gymnasium

# %% [markdown]
# # 0. Notebook description
# In this notebook, we will pass the image of the road and surrounding vehicles (like those displayed during the video animations of model evaluation) to the algorithm.
# Each agent that we train in this notebook will be using the GrayscaleObservation type, instead of Kinematics, as in the previous notebooks.
#
# We first train agents with the default reward function and our custom reward function using a CnnPolicy. In addition, we train agents with both reward functions using the MlpPolicy.
# CnnPolicy is specifically designed for image-based input data, using a CNN to process the image inputs, which is ideal for this use case.
# However, we have been using MlpPolicy as our default policy in every notebook until now, which works with 1D/flat vectors. We were curious to see whether an agent would still be able to extract any useful information from the images, using this policy.

# %% [markdown]
# # 1. Default reward function with CNN policy

# %% [markdown]
# We use the observation configuration specified in the highway-env documentation, where we specify that we want a 128 by 64 pixel image (the observation_shape) parameter, passing 4 images at a time as input (using the stack_size) parameter.
# Below, we train the agent with a default reward function on these images.

# %%
config_updates = {
    "observation": {
        "type": "GrayscaleObservation",
        "observation_shape": (128, 64),
        "stack_size": 4,
        "weights": [0.2989, 0.5870, 0.1140],  # weights for RGB conversion
        "scaling": 1.75,
    },
}

register(
    id='DefaultRewardEnv',
    entry_point='HighwayEnvDefaultReward:HighwayEnvDefaultReward',
)

# %%
log_filename="6_dqn_image_default_reward_log_cnnpolicy.csv"
log_performance_metrics_enabled=False

# %%
env = gymnasium.make("DefaultRewardEnv", 
                         config=config_updates, 
                     log_performance_metrics_enabled=log_performance_metrics_enabled, 
                     log_filename=log_filename, 
                         )
train_model(
    env=env,
    config_updates=config_updates,
    session_name='6_Group15_RLProject_dqn_default_image_cnnpolicy',
    policy="CnnPolicy"

)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'observation_shape': (128, 64),
#                  'scaling': 1.75,
#                  'stack_size': 4,
#                  'type': 'GrayscaleObservation',
#                  'weights': [0.2989, 0.587, 0.114]},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Training with policy CnnPolicy
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /Users/dora/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 65.55GB > 5.09GB
#   warnings.warn(
# Logging to ./logs/tensorboard/6_Group15_RLProject_dqn_default_image_cnnpolicy_DQN/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 105      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 57       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 92       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 117      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.327    |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 9.44     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 83       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 148      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 11       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 7.96     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 79       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 168      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0958   |
# |    n_updates        | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.73     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 73       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 228      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0392   |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.53     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 71       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 268      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 41       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 69       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 308      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0581   |
# |    n_updates        | 51       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.21     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 68       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 339      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0319   |
# |    n_updates        | 59       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 8.07     |
# |    exploration_rate | 0.823    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 67       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 373      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0495   |
# |    n_updates        | 68       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.87     |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 66       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 404      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00963  |
# |    n_updates        | 75       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 7.55     |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 66       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 429      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0325   |
# |    n_updates        | 82       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.77     |
# |    exploration_rate | 0.771    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 65       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 482      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0516   |
# |    n_updates        | 95       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.67     |
# |    ep_rew_mean      | 7.48     |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 64       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 503      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0339   |
# |    n_updates        | 100      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.77     |
# |    ep_rew_mean      | 7.54     |
# |    exploration_rate | 0.74     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 64       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 547      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0567   |
# |    n_updates        | 111      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8      |
# |    ep_rew_mean      | 7.61     |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 64       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 588      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 121      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8      |
# |    ep_rew_mean      | 7.61     |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 63       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 627      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.041    |
# |    n_updates        | 131      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.82     |
# |    ep_rew_mean      | 7.62     |
# |    exploration_rate | 0.683    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 63       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 668      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 141      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71     |
# |    ep_rew_mean      | 7.53     |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 63       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 699      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0275   |
# |    n_updates        | 149      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.79     |
# |    exploration_rate | 0.639    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 63       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 760      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0387   |
# |    n_updates        | 164      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.83     |
# |    exploration_rate | 0.619    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 63       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 802      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0389   |
# |    n_updates        | 175      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.81     |
# |    ep_rew_mean      | 7.67     |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 63       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 824      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00515  |
# |    n_updates        | 180      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.89     |
# |    ep_rew_mean      | 7.75     |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 62       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 870      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71     |
# |    ep_rew_mean      | 7.6      |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 62       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 893      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0394   |
# |    n_updates        | 198      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.76     |
# |    ep_rew_mean      | 7.68     |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 62       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 937      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0309   |
# |    n_updates        | 209      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.71     |
# |    ep_rew_mean      | 7.65     |
# |    exploration_rate | 0.539    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 62       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 971      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 217      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.43     |
# |    ep_rew_mean      | 7.44     |
# |    exploration_rate | 0.525    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 62       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 1000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0497   |
# |    n_updates        | 224      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.14     |
# |    ep_rew_mean      | 7.22     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 61       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 1031     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0426   |
# |    n_updates        | 232      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.12     |
# |    ep_rew_mean      | 7.23     |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 61       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1060     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 239      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.32     |
# |    ep_rew_mean      | 7.41     |
# |    exploration_rate | 0.477    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 61       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1100     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0385   |
# |    n_updates        | 249      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.13     |
# |    ep_rew_mean      | 7.27     |
# |    exploration_rate | 0.458    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 61       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1141     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0556   |
# |    n_updates        | 260      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.02     |
# |    ep_rew_mean      | 7.19     |
# |    exploration_rate | 0.444    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 61       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 1170     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 267      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.88     |
# |    ep_rew_mean      | 7.05     |
# |    exploration_rate | 0.432    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 61       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 1196     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0263   |
# |    n_updates        | 273      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.84     |
# |    ep_rew_mean      | 7.03     |
# |    exploration_rate | 0.419    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 61       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 1223     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 280      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.72     |
# |    ep_rew_mean      | 6.92     |
# |    exploration_rate | 0.409    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 61       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1245     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0534   |
# |    n_updates        | 286      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.81     |
# |    ep_rew_mean      | 7        |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 60       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1285     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0463   |
# |    n_updates        | 296      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.92     |
# |    ep_rew_mean      | 7.09     |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 60       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1321     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 305      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.85     |
# |    ep_rew_mean      | 7.09     |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 60       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1367     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0617   |
# |    n_updates        | 316      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.85     |
# |    ep_rew_mean      | 7.08     |
# |    exploration_rate | 0.341    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 60       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1388     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 321      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.65     |
# |    ep_rew_mean      | 6.93     |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 60       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1412     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0373   |
# |    n_updates        | 327      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.67     |
# |    ep_rew_mean      | 6.94     |
# |    exploration_rate | 0.309    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 60       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1455     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 338      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.62     |
# |    ep_rew_mean      | 6.92     |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 60       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1489     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 347      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.38     |
# |    ep_rew_mean      | 6.74     |
# |    exploration_rate | 0.285    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 60       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1506     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0352   |
# |    n_updates        | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.4      |
# |    ep_rew_mean      | 6.79     |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 60       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1539     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0486   |
# |    n_updates        | 359      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.12     |
# |    ep_rew_mean      | 6.55     |
# |    exploration_rate | 0.253    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 60       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1572     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0559   |
# |    n_updates        | 367      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.07     |
# |    ep_rew_mean      | 6.49     |
# |    exploration_rate | 0.236    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 59       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1609     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 377      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.27     |
# |    ep_rew_mean      | 6.64     |
# |    exploration_rate | 0.216    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 59       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1651     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0284   |
# |    n_updates        | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09     |
# |    ep_rew_mean      | 6.49     |
# |    exploration_rate | 0.202    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 59       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1679     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0495   |
# |    n_updates        | 394      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.2      |
# |    ep_rew_mean      | 6.6      |
# |    exploration_rate | 0.186    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 59       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1713     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0397   |
# |    n_updates        | 403      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.08     |
# |    ep_rew_mean      | 6.49     |
# |    exploration_rate | 0.171    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 59       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1745     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 411      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.2      |
# |    ep_rew_mean      | 6.59     |
# |    exploration_rate | 0.149    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 59       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 1791     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.048    |
# |    n_updates        | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.19     |
# |    ep_rew_mean      | 6.58     |
# |    exploration_rate | 0.136    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 59       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 1819     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 429      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.41     |
# |    ep_rew_mean      | 6.77     |
# |    exploration_rate | 0.111    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 59       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 1872     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0463   |
# |    n_updates        | 442      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.58     |
# |    ep_rew_mean      | 6.89     |
# |    exploration_rate | 0.089    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 59       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 1918     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0418   |
# |    n_updates        | 454      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.47     |
# |    ep_rew_mean      | 6.82     |
# |    exploration_rate | 0.0752   |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 59       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 1947     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 461      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.45     |
# |    ep_rew_mean      | 6.83     |
# |    exploration_rate | 0.0567   |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 59       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 1986     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 471      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.51     |
# |    ep_rew_mean      | 6.89     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 59       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 2021     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0576   |
# |    n_updates        | 480      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.65     |
# |    ep_rew_mean      | 7.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 59       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 2061     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 490      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.81     |
# |    ep_rew_mean      | 7.18     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 59       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 2104     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 500      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.82     |
# |    ep_rew_mean      | 7.2      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 58       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2127     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 506      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.71     |
# |    ep_rew_mean      | 7.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 58       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2156     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0518   |
# |    n_updates        | 513      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.69     |
# |    ep_rew_mean      | 7.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 58       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 2190     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0693   |
# |    n_updates        | 522      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.44     |
# |    ep_rew_mean      | 6.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 58       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 2211     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0302   |
# |    n_updates        | 527      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.77     |
# |    ep_rew_mean      | 7.19     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 58       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 2265     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 541      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9        |
# |    ep_rew_mean      | 7.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 58       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 2312     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0289   |
# |    n_updates        | 552      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.81     |
# |    ep_rew_mean      | 7.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 58       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 2336     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0321   |
# |    n_updates        | 558      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.82     |
# |    ep_rew_mean      | 7.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 58       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 2371     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 567      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.04     |
# |    ep_rew_mean      | 7.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 58       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 2410     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 577      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.01     |
# |    ep_rew_mean      | 7.42     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 58       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 2440     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0609   |
# |    n_updates        | 584      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.06     |
# |    ep_rew_mean      | 7.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 58       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 2478     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0345   |
# |    n_updates        | 594      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.98     |
# |    ep_rew_mean      | 7.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 58       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 2507     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0464   |
# |    n_updates        | 601      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.91     |
# |    ep_rew_mean      | 7.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 58       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 2542     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.063    |
# |    n_updates        | 610      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.24     |
# |    ep_rew_mean      | 7.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 58       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 2603     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 625      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.32     |
# |    ep_rew_mean      | 7.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 58       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2645     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0327   |
# |    n_updates        | 636      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.29     |
# |    ep_rew_mean      | 7.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 58       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2674     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0836   |
# |    n_updates        | 643      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.33     |
# |    ep_rew_mean      | 7.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 58       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 2724     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 655      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.52     |
# |    ep_rew_mean      | 7.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 58       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2771     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0371   |
# |    n_updates        | 667      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.36     |
# |    ep_rew_mean      | 7.89     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 58       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 2808     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0488   |
# |    n_updates        | 676      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.24     |
# |    ep_rew_mean      | 7.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 58       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 2842     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 685      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.33     |
# |    ep_rew_mean      | 7.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 57       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 2880     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 694      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.15     |
# |    ep_rew_mean      | 7.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 57       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2901     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 700      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.17     |
# |    ep_rew_mean      | 7.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 57       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2938     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0478   |
# |    n_updates        | 709      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.24     |
# |    ep_rew_mean      | 7.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 57       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 2985     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0528   |
# |    n_updates        | 721      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.12     |
# |    ep_rew_mean      | 7.65     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 57       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 3016     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0373   |
# |    n_updates        | 728      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.39     |
# |    ep_rew_mean      | 7.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 57       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 3066     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 741      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.28     |
# |    ep_rew_mean      | 7.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 57       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 3084     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 745      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.26     |
# |    ep_rew_mean      | 7.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 57       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 3116     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 753      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.68     |
# |    ep_rew_mean      | 8.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 57       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 3179     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0553   |
# |    n_updates        | 769      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.3      |
# |    ep_rew_mean      | 7.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 57       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 3195     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 773      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.41     |
# |    ep_rew_mean      | 7.89     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 57       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 3253     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 788      |
# ----------------------------------
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0915   |
# |    n_updates        | 4653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2004     |
# |    fps              | 52       |
# |    time_elapsed     | 359      |
# |    total_timesteps  | 18774    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 4668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 9.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2008     |
# |    fps              | 52       |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 18832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 4682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2012     |
# |    fps              | 52       |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 18860    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 4689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2016     |
# |    fps              | 52       |
# |    time_elapsed     | 361      |
# |    total_timesteps  | 18884    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 4695     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2020     |
# |    fps              | 52       |
# |    time_elapsed     | 363      |
# |    total_timesteps  | 18936    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0533   |
# |    n_updates        | 4708     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 9.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2024     |
# |    fps              | 52       |
# |    time_elapsed     | 363      |
# |    total_timesteps  | 18962    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0534   |
# |    n_updates        | 4715     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 9.03     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2028     |
# |    fps              | 52       |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 19001    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0683   |
# |    n_updates        | 4725     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 9.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2032     |
# |    fps              | 52       |
# |    time_elapsed     | 365      |
# |    total_timesteps  | 19053    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00293  |
# |    n_updates        | 4738     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2036     |
# |    fps              | 52       |
# |    time_elapsed     | 366      |
# |    total_timesteps  | 19089    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0427   |
# |    n_updates        | 4747     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 9.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2040     |
# |    fps              | 52       |
# |    time_elapsed     | 367      |
# |    total_timesteps  | 19159    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.088    |
# |    n_updates        | 4764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.18     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2044     |
# |    fps              | 52       |
# |    time_elapsed     | 368      |
# |    total_timesteps  | 19206    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 4776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 9.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2048     |
# |    fps              | 52       |
# |    time_elapsed     | 369      |
# |    total_timesteps  | 19273    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 4793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 9.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2052     |
# |    fps              | 52       |
# |    time_elapsed     | 370      |
# |    total_timesteps  | 19323    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0435   |
# |    n_updates        | 4805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2056     |
# |    fps              | 52       |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 19399    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 4824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 9.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2060     |
# |    fps              | 52       |
# |    time_elapsed     | 373      |
# |    total_timesteps  | 19430    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0457   |
# |    n_updates        | 4832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 9.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2064     |
# |    fps              | 52       |
# |    time_elapsed     | 373      |
# |    total_timesteps  | 19461    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0752   |
# |    n_updates        | 4840     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 9.33     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2068     |
# |    fps              | 52       |
# |    time_elapsed     | 374      |
# |    total_timesteps  | 19490    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.082    |
# |    n_updates        | 4847     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 9.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2072     |
# |    fps              | 52       |
# |    time_elapsed     | 375      |
# |    total_timesteps  | 19528    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 4856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2076     |
# |    fps              | 52       |
# |    time_elapsed     | 375      |
# |    total_timesteps  | 19545    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0737   |
# |    n_updates        | 4861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2080     |
# |    fps              | 52       |
# |    time_elapsed     | 376      |
# |    total_timesteps  | 19582    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 4870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2084     |
# |    fps              | 52       |
# |    time_elapsed     | 377      |
# |    total_timesteps  | 19635    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0283   |
# |    n_updates        | 4883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2088     |
# |    fps              | 52       |
# |    time_elapsed     | 378      |
# |    total_timesteps  | 19671    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 4892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2092     |
# |    fps              | 52       |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 19725    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0825   |
# |    n_updates        | 4906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.04     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2096     |
# |    fps              | 52       |
# |    time_elapsed     | 380      |
# |    total_timesteps  | 19784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 4920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 52       |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 19819    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.049    |
# |    n_updates        | 4929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2104     |
# |    fps              | 52       |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 19837    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 4934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2108     |
# |    fps              | 51       |
# |    time_elapsed     | 382      |
# |    total_timesteps  | 19888    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0621   |
# |    n_updates        | 4946     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2112     |
# |    fps              | 51       |
# |    time_elapsed     | 383      |
# |    total_timesteps  | 19919    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 4954     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2116     |
# |    fps              | 51       |
# |    time_elapsed     | 383      |
# |    total_timesteps  | 19955    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 4963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.62     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2120     |
# |    fps              | 51       |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 19997    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 4974     |
# ----------------------------------
# Model saved to ./models/6_Group15_RLProject_dqn_default_image_cnnpolicy

# %%
log_performance_metrics_enabled=True



env = gymnasium.make('DefaultRewardEnv', 
                     render_mode='rgb_array', 
                    log_performance_metrics_enabled=log_performance_metrics_enabled,
                     log_filename=log_filename
                     )

# evaluate the model with the default reward function
evaluate_model(
    env=env,
    config_updates={**config_updates, "simulation_frequency": 15},
    model_path="models/6_Group15_RLProject_dqn_default_image_cnnpolicy",
    algorithm='DQN',
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'observation_shape': (128, 64),
#                  'scaling': 1.75,
#                  'stack_size': 4,
#                  'type': 'GrayscaleObservation',
#                  'weights': [0.2989, 0.587, 0.114]},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Loading model with path models/6_Group15_RLProject_dqn_default_image_cnnpolicy
# Logging metrics for step 15 and seconds elapsed 1.0
# /Users/dora/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 65.55GB > 4.60GB
#   warnings.warn(
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# ...
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0

# %%
metrics = aggregate_and_normalize_rewards(log_filename)

if metrics:
    print("Performance metric (as percent of all steps):")
    for metric_name, avg_metric in metrics.items():
        print(f"{metric_name}: {avg_metric*100:.4f}%")
# Out:
# Performance metric (as percent of all steps):
# collision_count: 7.0666%
# right_lane_count: 70.0493%
# on_road_count: 100.0000%
# safe_distance_count: 94.7412%
# left_vehicle_overtaken_count: 8.2169%
# abrupt_accelerations_count: 30.8135%

# %% [markdown]
# The model trained with the default reward function on images of the highway collides at a rate of 7% of all recorded steps, and was not in the leftmost lane for 70% of steps.

# %% [markdown]
# # 2. Custom reward function with CNN policy

# %% [markdown]
# Below, we train a model with our custom reward function using the DQN algorithm, and inspect its performance on our predefined metrics.

# %%
config_updates = {
    "safe_distance_reward": 0.1,
    "left_vehicle_overtaken_reward": -0.5,
    "collision_reward": -4,
    "smooth_driving_reward" : 0.3,
    "right_lane_reward" : 0.5, 
    "observation": {
        "type": "GrayscaleObservation",
        "observation_shape": (128, 64),
        "stack_size": 4,
        "weights": [0.2989, 0.5870, 0.1140],  # weights for RGB conversion
        "scaling": 1.75,
    },
}

# Register the custom environment
register(
    id='CustomRewardEnv',
    entry_point='HighwayEnvCustomReward:HighwayEnvFastCustomReward',
)

# %%
# Create the environment with the custom parameter
# Set log_rewards_enabled to True or False as per your requirement
log_filename="6_dqn_image_custom_reward_log_cnnpolicy.csv"
log_performance_metrics_enabled=False

# %%
env = gymnasium.make("CustomRewardEnv", 
                    config=config_updates, 
                     log_performance_metrics_enabled=log_performance_metrics_enabled,
                     log_filename=log_filename
                         )
train_model(
    env=env,
    config_updates=config_updates,
    session_name='6_Group15_RLProject_dqn_custom_image_cnnpolicy',
    policy="CnnPolicy"

)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'observation_shape': (128, 64),
#                  'scaling': 1.75,
#                  'stack_size': 4,
#                  'type': 'GrayscaleObservation',
#                  'weights': [0.2989, 0.587, 0.114]},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.5,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'smooth_driving_reward': 0.3,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Training with policy CnnPolicy
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/tensorboard/6_Group15_RLProject_dqn_custom_image_cnnpolicy_DQN/DQN_1
# /Users/dora/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 65.55GB > 4.72GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9        |
# |    ep_rew_mean      | 7.33     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 84       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 91       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 107      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.41     |
# |    n_updates        | 1        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 77       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 145      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.226    |
# |    n_updates        | 11       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 9.06     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 72       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 175      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0529   |
# |    n_updates        | 18       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.7      |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 67       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 210      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00993  |
# |    n_updates        | 27       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.92     |
# |    ep_rew_mean      | 8.14     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 65       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 238      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 34       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.81     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 61       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 299      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 49       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.68     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 59       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 336      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 9.45     |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 57       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 407      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 76       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 9.19     |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 56       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 441      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 85       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.71     |
# |    exploration_rate | 0.781    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 56       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 462      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 90       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 55       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 495      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0291   |
# |    n_updates        | 98       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.67     |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 55       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 544      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 110      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 8.62     |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 54       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 582      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 8.43     |
# |    exploration_rate | 0.71     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 54       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 610      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 127      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 8.41     |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 54       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 649      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.038    |
# |    n_updates        | 137      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 8.62     |
# |    exploration_rate | 0.665    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 53       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 706      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 151      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.72     |
# |    exploration_rate | 0.641    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 53       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 755      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 163      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.91     |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 53       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 812      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.04     |
# |    n_updates        | 177      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.8      |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 52       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 845      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 186      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.83     |
# |    exploration_rate | 0.577    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 52       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 890      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 197      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.7      |
# |    exploration_rate | 0.563    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 52       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 920      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00943  |
# |    n_updates        | 204      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 9.03     |
# |    exploration_rate | 0.527    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 51       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 995      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 223      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.91     |
# |    exploration_rate | 0.513    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 51       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 1026     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0338   |
# |    n_updates        | 231      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.75     |
# |    exploration_rate | 0.501    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 51       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1051     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0439   |
# |    n_updates        | 237      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 9.2      |
# |    exploration_rate | 0.461    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 51       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1134     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0339   |
# |    n_updates        | 258      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.96     |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 50       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1176     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.046    |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.95     |
# |    exploration_rate | 0.424    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 50       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1212     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 277      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 9.22     |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 50       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1272     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 292      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 9.2      |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 50       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1304     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 300      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.48     |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 50       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1361     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 315      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 9.23     |
# |    exploration_rate | 0.338    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 50       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1393     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 323      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 9.18     |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 49       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1425     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0421   |
# |    n_updates        | 331      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 8.87     |
# |    exploration_rate | 0.306    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 49       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1461     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 340      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 9.39     |
# |    exploration_rate | 0.262    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 49       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 1554     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00373  |
# |    n_updates        | 363      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.68     |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 49       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 1605     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00473  |
# |    n_updates        | 376      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.63     |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 49       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 1632     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 9.61     |
# |    exploration_rate | 0.203    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 49       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 1678     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 394      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 9.62     |
# |    exploration_rate | 0.185    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 49       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 1716     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.027    |
# |    n_updates        | 403      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.53     |
# |    exploration_rate | 0.176    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 49       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 1735     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0267   |
# |    n_updates        | 408      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.5      |
# |    exploration_rate | 0.159    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 49       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 1771     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0205   |
# |    n_updates        | 417      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 9.25     |
# |    exploration_rate | 0.145    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 48       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 1799     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0331   |
# |    n_updates        | 424      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 9.56     |
# |    exploration_rate | 0.107    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 48       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 1881     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 445      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 9.85     |
# |    exploration_rate | 0.0642   |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 48       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 1970     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0336   |
# |    n_updates        | 467      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 48       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 2052     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 487      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 48       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 2122     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0326   |
# |    n_updates        | 505      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 48       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 2179     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0265   |
# |    n_updates        | 519      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 48       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2219     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00281  |
# |    n_updates        | 529      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 48       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2276     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 543      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 48       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 2357     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 564      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 48       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 2433     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 583      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 48       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 2522     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00711  |
# |    n_updates        | 605      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 47       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 2584     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 620      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 47       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 2648     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.038    |
# |    n_updates        | 636      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 47       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 2728     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 656      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 47       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 2848     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 686      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 47       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 2907     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 701      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 47       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 3004     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 725      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 47       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 3098     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 749      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 47       |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 3176     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0344   |
# |    n_updates        | 768      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 47       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 3230     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 782      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 47       |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 3271     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0409   |
# |    n_updates        | 792      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 47       |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 3368     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 816      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.5     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 47       |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 3464     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 840      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 47       |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 3522     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 855      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 47       |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 3595     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00973  |
# |    n_updates        | 873      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 47       |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 3675     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00932  |
# |    n_updates        | 893      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.6     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 47       |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 3737     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00738  |
# |    n_updates        | 909      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18       |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 47       |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 3773     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 918      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 47       |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 3872     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0173   |
# |    n_updates        | 942      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 47       |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 3947     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 961      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 47       |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 4017     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 979      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 47       |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 4105     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 1001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 47       |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 4201     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 1025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 47       |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 4321     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 1055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 47       |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 4401     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 1075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 17.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 47       |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 4471     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 1092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 47       |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 4583     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 1120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 47       |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 4665     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 1141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 47       |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 4773     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 1168     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.2     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 47       |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 4869     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00114  |
# |    n_updates        | 1192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 47       |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 4909     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 1202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.9     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 47       |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 4993     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00871  |
# |    n_updates        | 1223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 47       |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 5062     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 1240     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 47       |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 5147     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00375  |
# |    n_updates        | 1261     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.7     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 47       |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 5199     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 1274     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 47       |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 5313     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00721  |
# |    n_updates        | 1303     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.4     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 46       |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 5407     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 1326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 46       |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 5527     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0525   |
# |    n_updates        | 4396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.6     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 45       |
# |    time_elapsed     | 388      |
# |    total_timesteps  | 17770    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 4417     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.9     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 45       |
# |    time_elapsed     | 389      |
# |    total_timesteps  | 17811    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 4427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 45       |
# |    time_elapsed     | 390      |
# |    total_timesteps  | 17873    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0422   |
# |    n_updates        | 4443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 45       |
# |    time_elapsed     | 392      |
# |    total_timesteps  | 17950    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0448   |
# |    n_updates        | 4462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 45       |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 18055    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0028   |
# |    n_updates        | 4488     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.3     |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 45       |
# |    time_elapsed     | 396      |
# |    total_timesteps  | 18159    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0376   |
# |    n_updates        | 4514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 45       |
# |    time_elapsed     | 398      |
# |    total_timesteps  | 18236    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 4533     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 45       |
# |    time_elapsed     | 400      |
# |    total_timesteps  | 18319    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0632   |
# |    n_updates        | 4554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 45       |
# |    time_elapsed     | 401      |
# |    total_timesteps  | 18370    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00514  |
# |    n_updates        | 4567     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 45       |
# |    time_elapsed     | 403      |
# |    total_timesteps  | 18490    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0049   |
# |    n_updates        | 4597     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 45       |
# |    time_elapsed     | 404      |
# |    total_timesteps  | 18540    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0358   |
# |    n_updates        | 4609     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 45       |
# |    time_elapsed     | 406      |
# |    total_timesteps  | 18616    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0691   |
# |    n_updates        | 4628     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 45       |
# |    time_elapsed     | 408      |
# |    total_timesteps  | 18728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00311  |
# |    n_updates        | 4656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.6     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 45       |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 18836    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0995   |
# |    n_updates        | 4683     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20       |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 45       |
# |    time_elapsed     | 412      |
# |    total_timesteps  | 18905    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0393   |
# |    n_updates        | 4701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.5     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 45       |
# |    time_elapsed     | 413      |
# |    total_timesteps  | 18947    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0032   |
# |    n_updates        | 4711     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.1     |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 45       |
# |    time_elapsed     | 414      |
# |    total_timesteps  | 18983    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0815   |
# |    n_updates        | 4720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 45       |
# |    time_elapsed     | 415      |
# |    total_timesteps  | 19017    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.038    |
# |    n_updates        | 4729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.6     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 45       |
# |    time_elapsed     | 416      |
# |    total_timesteps  | 19078    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 4744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.4     |
# |    ep_rew_mean      | 16.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 45       |
# |    time_elapsed     | 418      |
# |    total_timesteps  | 19173    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0434   |
# |    n_updates        | 4768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 45       |
# |    time_elapsed     | 420      |
# |    total_timesteps  | 19260    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 4789     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 45       |
# |    time_elapsed     | 421      |
# |    total_timesteps  | 19294    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00109  |
# |    n_updates        | 4798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.5     |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 45       |
# |    time_elapsed     | 424      |
# |    total_timesteps  | 19414    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0404   |
# |    n_updates        | 4828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.7     |
# |    ep_rew_mean      | 16.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 45       |
# |    time_elapsed     | 425      |
# |    total_timesteps  | 19487    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 4846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.9     |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 45       |
# |    time_elapsed     | 427      |
# |    total_timesteps  | 19581    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0369   |
# |    n_updates        | 4870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 45       |
# |    time_elapsed     | 429      |
# |    total_timesteps  | 19653    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0383   |
# |    n_updates        | 4888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.2     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 45       |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 19736    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00303  |
# |    n_updates        | 4908     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 45       |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 19777    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0319   |
# |    n_updates        | 4919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19.3     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 45       |
# |    time_elapsed     | 434      |
# |    total_timesteps  | 19876    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0752   |
# |    n_updates        | 4943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 19       |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 45       |
# |    time_elapsed     | 436      |
# |    total_timesteps  | 19957    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00213  |
# |    n_updates        | 4964     |
# ----------------------------------
# Model saved to ./models/6_Group15_RLProject_dqn_custom_image_cnnpolicy

# %%
log_performance_metrics_enabled=True

env = gymnasium.make('CustomRewardEnv', 
                     render_mode='rgb_array', 
                     log_performance_metrics_enabled=log_performance_metrics_enabled, 
                     log_filename=log_filename, 
                     config=config_updates
                    )
evaluate_model(
    env=env,
    config_updates={**config_updates, "simulation_frequency": 15},
    model_path='models/6_Group15_RLProject_dqn_custom_image_cnnpolicy',
    algorithm='DQN',
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'observation_shape': (128, 64),
#                  'scaling': 1.75,
#                  'stack_size': 4,
#                  'type': 'GrayscaleObservation',
#                  'weights': [0.2989, 0.587, 0.114]},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.5,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'smooth_driving_reward': 0.3,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Loading model with path models/6_Group15_RLProject_dqn_custom_image_cnnpolicy
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# /Users/dora/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 65.55GB > 3.96GB
#   warnings.warn(
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# ...
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0

# %%
metrics = aggregate_and_normalize_rewards(log_filename)

if metrics:
    print("Performance metric (as percent of all steps):")
    for metric_name, avg_metric in metrics.items():
        print(f"{metric_name}: {avg_metric*100:.4f}%")
# Out:
# Performance metric (as percent of all steps):
# collision_count: 0.8486%
# right_lane_count: 100.0000%
# on_road_count: 100.0000%
# safe_distance_count: 99.7434%
# left_vehicle_overtaken_count: 2.0920%
# abrupt_accelerations_count: 4.2431%

# %% [markdown]
# # 3. Default reward function with MlpPolicy

# %%
config_updates = {
    "observation": {
        "type": "GrayscaleObservation",
        "observation_shape": (128, 64),
        "stack_size": 4,
        "weights": [0.2989, 0.5870, 0.1140],  # weights for RGB conversion
        "scaling": 1.75,
    },
}

register(
    id='DefaultRewardEnv',
    entry_point='HighwayEnvDefaultReward:HighwayEnvDefaultReward',
)
# Out:
# /Users/dora/anaconda3/lib/python3.12/site-packages/gymnasium/envs/registration.py:642: UserWarning: WARN: Overriding environment DefaultRewardEnv already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
log_filename="6_dqn_image_default_reward_log_mlppolicy.csv"
log_performance_metrics_enabled=False

# %%
env = gymnasium.make("DefaultRewardEnv", 
                         config=config_updates, 
                     log_performance_metrics_enabled=log_performance_metrics_enabled, 
                     log_filename=log_filename, 
                         )
train_model(
    env=env,
    config_updates=config_updates,
    session_name='6_dqn_image_default_reward_log_mlppolicy',
    policy="MlpPolicy"

)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'observation_shape': (128, 64),
#                  'scaling': 1.75,
#                  'stack_size': 4,
#                  'type': 'GrayscaleObservation',
#                  'weights': [0.2989, 0.587, 0.114]},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Training with policy MlpPolicy
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/tensorboard/6_dqn_image_default_reward_log_mlppolicy_DQN/DQN_1
# /Users/dora/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 65.55GB > 3.88GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 7.73     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 84       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 44       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.25     |
# |    ep_rew_mean      | 5.91     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 89       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 66       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.67     |
# |    ep_rew_mean      | 5.66     |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 92       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.06     |
# |    ep_rew_mean      | 6.92     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 86       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 145      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0844   |
# |    n_updates        | 11       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.6      |
# |    ep_rew_mean      | 7.18     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 80       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 192      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0457   |
# |    n_updates        | 22       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.5      |
# |    ep_rew_mean      | 7.08     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 77       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 228      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0409   |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.39     |
# |    ep_rew_mean      | 7.04     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 74       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 263      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0395   |
# |    n_updates        | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.53     |
# |    ep_rew_mean      | 7.17     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 72       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 305      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0481   |
# |    n_updates        | 51       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.17     |
# |    ep_rew_mean      | 6.92     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 71       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 330      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0628   |
# |    n_updates        | 57       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.8      |
# |    ep_rew_mean      | 7.35     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 70       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 392      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.57     |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 69       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 440      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 84       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.57     |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 68       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 480      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 7.62     |
# |    exploration_rate | 0.75     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 68       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 526      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0331   |
# |    n_updates        | 106      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 7.52     |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 67       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 560      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0535   |
# |    n_updates        | 114      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.72     |
# |    ep_rew_mean      | 7.31     |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 67       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 583      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0364   |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.55     |
# |    ep_rew_mean      | 7.22     |
# |    exploration_rate | 0.71     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 67       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 611      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 127      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.43     |
# |    ep_rew_mean      | 7.14     |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 66       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 641      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0309   |
# |    n_updates        | 135      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.31     |
# |    ep_rew_mean      | 7.05     |
# |    exploration_rate | 0.682    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 66       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 670      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0474   |
# |    n_updates        | 142      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.05     |
# |    ep_rew_mean      | 6.84     |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 66       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 688      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 146      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.12     |
# |    ep_rew_mean      | 6.92     |
# |    exploration_rate | 0.653    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 66       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 730      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0512   |
# |    n_updates        | 157      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.93     |
# |    ep_rew_mean      | 6.78     |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 66       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 750      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0443   |
# |    n_updates        | 162      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.88     |
# |    ep_rew_mean      | 6.76     |
# |    exploration_rate | 0.629    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 65       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 781      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0638   |
# |    n_updates        | 170      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.85     |
# |    ep_rew_mean      | 6.73     |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 65       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 814      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 178      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.79     |
# |    ep_rew_mean      | 6.7      |
# |    exploration_rate | 0.599    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 65       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 844      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0537   |
# |    n_updates        | 185      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.02     |
# |    ep_rew_mean      | 6.88     |
# |    exploration_rate | 0.572    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 65       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 902      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0482   |
# |    n_updates        | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.93     |
# |    ep_rew_mean      | 6.85     |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 65       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 937      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 209      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.18     |
# |    ep_rew_mean      | 7.04     |
# |    exploration_rate | 0.533    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 65       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 984      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0483   |
# |    n_updates        | 220      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.32     |
# |    ep_rew_mean      | 7.18     |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 64       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 1024     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0433   |
# |    n_updates        | 230      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.26     |
# |    ep_rew_mean      | 7.11     |
# |    exploration_rate | 0.491    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 64       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 1071     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.061    |
# |    n_updates        | 242      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.16     |
# |    ep_rew_mean      | 7.08     |
# |    exploration_rate | 0.474    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 64       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1108     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 251      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.07     |
# |    ep_rew_mean      | 7.03     |
# |    exploration_rate | 0.461    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 64       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1135     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0422   |
# |    n_updates        | 258      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.05     |
# |    ep_rew_mean      | 7.02     |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 64       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1168     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0442   |
# |    n_updates        | 266      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.15     |
# |    ep_rew_mean      | 7.1      |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 64       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1220     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0568   |
# |    n_updates        | 279      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.75     |
# |    ep_rew_mean      | 7.6      |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 64       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1305     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0355   |
# |    n_updates        | 301      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.46     |
# |    ep_rew_mean      | 7.42     |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 64       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1338     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00787  |
# |    n_updates        | 309      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.16     |
# |    ep_rew_mean      | 7.15     |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 64       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1356     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 313      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.19     |
# |    ep_rew_mean      | 7.23     |
# |    exploration_rate | 0.335    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 64       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1399     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0422   |
# |    n_updates        | 324      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.06     |
# |    ep_rew_mean      | 7.16     |
# |    exploration_rate | 0.32     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 64       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1432     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0643   |
# |    n_updates        | 332      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.08     |
# |    ep_rew_mean      | 7.22     |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 64       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1468     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0515   |
# |    n_updates        | 341      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.11     |
# |    ep_rew_mean      | 7.25     |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 64       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1494     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0701   |
# |    n_updates        | 348      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.28     |
# |    ep_rew_mean      | 7.4      |
# |    exploration_rate | 0.269    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 64       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1539     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0425   |
# |    n_updates        | 359      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.2      |
# |    ep_rew_mean      | 7.33     |
# |    exploration_rate | 0.259    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 64       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1561     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 365      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.16     |
# |    ep_rew_mean      | 7.31     |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 63       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1586     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0347   |
# |    n_updates        | 371      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.3      |
# |    ep_rew_mean      | 7.44     |
# |    exploration_rate | 0.231    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 63       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1618     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0539   |
# |    n_updates        | 379      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.4      |
# |    ep_rew_mean      | 7.53     |
# |    exploration_rate | 0.207    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 63       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1670     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0435   |
# |    n_updates        | 392      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.56     |
# |    ep_rew_mean      | 7.68     |
# |    exploration_rate | 0.19     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 63       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1706     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0403   |
# |    n_updates        | 401      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.45     |
# |    ep_rew_mean      | 7.58     |
# |    exploration_rate | 0.18     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 63       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1726     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0518   |
# |    n_updates        | 406      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.39     |
# |    ep_rew_mean      | 7.56     |
# |    exploration_rate | 0.167    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 63       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1753     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0649   |
# |    n_updates        | 413      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.62     |
# |    ep_rew_mean      | 7.77     |
# |    exploration_rate | 0.142    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 63       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1806     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0497   |
# |    n_updates        | 426      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.42     |
# |    ep_rew_mean      | 7.61     |
# |    exploration_rate | 0.124    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 63       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1844     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 435      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.36     |
# |    ep_rew_mean      | 7.57     |
# |    exploration_rate | 0.11     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 63       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1873     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.037    |
# |    n_updates        | 443      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.1      |
# |    ep_rew_mean      | 7.38     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 63       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 1894     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 448      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.47     |
# |    ep_rew_mean      | 7.67     |
# |    exploration_rate | 0.0638   |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 63       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 1971     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0448   |
# |    n_updates        | 467      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.31     |
# |    ep_rew_mean      | 7.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 63       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 2002     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0247   |
# |    n_updates        | 475      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.28     |
# |    ep_rew_mean      | 7.56     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 63       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 2036     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0433   |
# |    n_updates        | 483      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.48     |
# |    ep_rew_mean      | 7.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 63       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 2083     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0413   |
# |    n_updates        | 495      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.46     |
# |    ep_rew_mean      | 7.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 63       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 2114     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 503      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.29     |
# |    ep_rew_mean      | 7.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 63       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 2149     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 512      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.72     |
# |    ep_rew_mean      | 7.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 63       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 2177     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00516  |
# |    n_updates        | 519      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.94     |
# |    ep_rew_mean      | 7.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 63       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 2232     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 532      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.05     |
# |    ep_rew_mean      | 7.46     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 63       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 2261     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0317   |
# |    n_updates        | 540      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.96     |
# |    ep_rew_mean      | 7.37     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 63       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2295     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.045    |
# |    n_updates        | 548      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.95     |
# |    ep_rew_mean      | 7.38     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 63       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2327     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0637   |
# |    n_updates        | 556      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.09     |
# |    ep_rew_mean      | 7.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 63       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 2377     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 569      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.29     |
# |    ep_rew_mean      | 7.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 63       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 2423     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0529   |
# |    n_updates        | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.16     |
# |    ep_rew_mean      | 7.52     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 63       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 2455     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0514   |
# |    n_updates        | 588      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.13     |
# |    ep_rew_mean      | 7.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 63       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 2474     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 593      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.05     |
# |    ep_rew_mean      | 7.44     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 63       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 2491     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 597      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.93     |
# |    ep_rew_mean      | 7.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 63       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 2511     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0516   |
# |    n_updates        | 602      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.68     |
# |    ep_rew_mean      | 7.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 63       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 2538     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0596   |
# |    n_updates        | 609      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.66     |
# |    ep_rew_mean      | 7.12     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 63       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 2572     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 617      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.71     |
# |    ep_rew_mean      | 7.18     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 63       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 2597     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 624      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.84     |
# |    ep_rew_mean      | 7.29     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 63       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 2637     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0263   |
# |    n_updates        | 634      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.56     |
# |    ep_rew_mean      | 7.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 63       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 2662     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 640      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.61     |
# |    ep_rew_mean      | 7.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 63       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 2705     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0391   |
# |    n_updates        | 651      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.78     |
# |    ep_rew_mean      | 7.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 63       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 2751     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 662      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.1      |
# |    ep_rew_mean      | 7.49     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 63       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 2804     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0471   |
# |    n_updates        | 675      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.63     |
# |    ep_rew_mean      | 7.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 63       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 2834     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0552   |
# |    n_updates        | 683      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.8      |
# |    ep_rew_mean      | 7.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 63       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2882     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0557   |
# |    n_updates        | 695      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.73     |
# |    ep_rew_mean      | 7.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 63       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 2909     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0527   |
# |    n_updates        | 702      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.55     |
# |    ep_rew_mean      | 6.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 63       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 2938     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 709      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.6      |
# |    ep_rew_mean      | 7.05     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 63       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 2974     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0551   |
# |    n_updates        | 718      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.41     |
# |    ep_rew_mean      | 6.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 63       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 2990     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0425   |
# |    n_updates        | 722      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.3      |
# |    ep_rew_mean      | 6.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 63       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 3007     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0678   |
# |    n_updates        | 726      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.02     |
# |    ep_rew_mean      | 6.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 63       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 3034     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0523   |
# |    n_updates        | 733      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.06     |
# |    ep_rew_mean      | 6.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 63       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 3067     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 741      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.91     |
# |    ep_rew_mean      | 6.45     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 63       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 3086     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00744  |
# |    n_updates        | 746      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.1      |
# |    ep_rew_mean      | 6.63     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 63       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 3137     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0429   |
# |    n_updates        | 759      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.89     |
# |    ep_rew_mean      | 6.49     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 63       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 3166     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 766      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.6      |
# |    ep_rew_mean      | 6.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 63       |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.174    |
# |    n_updates        | 4705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.03     |
# |    ep_rew_mean      | 6.75     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2156     |
# |    fps              | 62       |
# |    time_elapsed     | 304      |
# |    total_timesteps  | 18960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 4714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.01     |
# |    ep_rew_mean      | 6.66     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2160     |
# |    fps              | 62       |
# |    time_elapsed     | 305      |
# |    total_timesteps  | 19004    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 4725     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.09     |
# |    ep_rew_mean      | 6.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2164     |
# |    fps              | 62       |
# |    time_elapsed     | 305      |
# |    total_timesteps  | 19040    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0701   |
# |    n_updates        | 4734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.1      |
# |    ep_rew_mean      | 6.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2168     |
# |    fps              | 62       |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 19064    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 4740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.36     |
# |    ep_rew_mean      | 6.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2172     |
# |    fps              | 62       |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 19129    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0982   |
# |    n_updates        | 4757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.48     |
# |    ep_rew_mean      | 7.07     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2176     |
# |    fps              | 62       |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 19154    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0808   |
# |    n_updates        | 4763     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.49     |
# |    ep_rew_mean      | 7.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2180     |
# |    fps              | 62       |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 19186    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.18     |
# |    n_updates        | 4771     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.51     |
# |    ep_rew_mean      | 7.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2184     |
# |    fps              | 62       |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 19217    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.099    |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.34     |
# |    ep_rew_mean      | 6.94     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2188     |
# |    fps              | 62       |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 19239    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.121    |
# |    n_updates        | 4784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.39     |
# |    ep_rew_mean      | 6.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2192     |
# |    fps              | 62       |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 19265    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.244    |
# |    n_updates        | 4791     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.31     |
# |    ep_rew_mean      | 6.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2196     |
# |    fps              | 62       |
# |    time_elapsed     | 310      |
# |    total_timesteps  | 19304    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 4800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.33     |
# |    ep_rew_mean      | 6.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 62       |
# |    time_elapsed     | 310      |
# |    total_timesteps  | 19341    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 4810     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.03     |
# |    ep_rew_mean      | 6.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2204     |
# |    fps              | 62       |
# |    time_elapsed     | 311      |
# |    total_timesteps  | 19364    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0742   |
# |    n_updates        | 4815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.02     |
# |    ep_rew_mean      | 6.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 62       |
# |    time_elapsed     | 311      |
# |    total_timesteps  | 19387    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.11     |
# |    n_updates        | 4821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.16     |
# |    ep_rew_mean      | 6.78     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 62       |
# |    time_elapsed     | 312      |
# |    total_timesteps  | 19452    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0772   |
# |    n_updates        | 4837     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.1      |
# |    ep_rew_mean      | 6.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 62       |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 19472    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0731   |
# |    n_updates        | 4842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.15     |
# |    ep_rew_mean      | 6.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2220     |
# |    fps              | 62       |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 19511    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0718   |
# |    n_updates        | 4852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.39     |
# |    ep_rew_mean      | 6.91     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 62       |
# |    time_elapsed     | 314      |
# |    total_timesteps  | 19557    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.147    |
# |    n_updates        | 4864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.35     |
# |    ep_rew_mean      | 6.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 62       |
# |    time_elapsed     | 315      |
# |    total_timesteps  | 19583    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.138    |
# |    n_updates        | 4870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.6      |
# |    ep_rew_mean      | 7.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2232     |
# |    fps              | 62       |
# |    time_elapsed     | 315      |
# |    total_timesteps  | 19628    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0398   |
# |    n_updates        | 4881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.58     |
# |    ep_rew_mean      | 7.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2236     |
# |    fps              | 62       |
# |    time_elapsed     | 316      |
# |    total_timesteps  | 19659    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0784   |
# |    n_updates        | 4889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.78     |
# |    ep_rew_mean      | 7.24     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2240     |
# |    fps              | 62       |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 19704    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.172    |
# |    n_updates        | 4900     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.63     |
# |    ep_rew_mean      | 7.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2244     |
# |    fps              | 62       |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 19728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.128    |
# |    n_updates        | 4906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.92     |
# |    ep_rew_mean      | 7.31     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2248     |
# |    fps              | 62       |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 19779    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0473   |
# |    n_updates        | 4919     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.82     |
# |    ep_rew_mean      | 7.22     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2252     |
# |    fps              | 62       |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 19805    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0748   |
# |    n_updates        | 4926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.75     |
# |    ep_rew_mean      | 7.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2256     |
# |    fps              | 62       |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 19835    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0979   |
# |    n_updates        | 4933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.61     |
# |    ep_rew_mean      | 7.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2260     |
# |    fps              | 62       |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 19865    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.139    |
# |    n_updates        | 4941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.49     |
# |    ep_rew_mean      | 6.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2264     |
# |    fps              | 62       |
# |    time_elapsed     | 320      |
# |    total_timesteps  | 19889    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.167    |
# |    n_updates        | 4947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.57     |
# |    ep_rew_mean      | 7.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2268     |
# |    fps              | 62       |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 19921    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.159    |
# |    n_updates        | 4955     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.14     |
# |    ep_rew_mean      | 6.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2272     |
# |    fps              | 62       |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 19943    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.172    |
# |    n_updates        | 4960     |
# ----------------------------------
# Model saved to ./models/6_dqn_image_default_reward_log_mlppolicy

# %%
log_performance_metrics_enabled=True



env = gymnasium.make('DefaultRewardEnv', 
                     render_mode='rgb_array', 
                    log_performance_metrics_enabled=log_performance_metrics_enabled,
                     log_filename=log_filename
                     )

# evaluate the model with the default reward function
evaluate_model(
    env=env,
    config_updates={**config_updates, "simulation_frequency": 15},
    model_path="models/6_dqn_image_default_reward_log_mlppolicy",
    algorithm='DQN',
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -1,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'observation_shape': (128, 64),
#                  'scaling': 1.75,
#                  'stack_size': 4,
#                  'type': 'GrayscaleObservation',
#                  'weights': [0.2989, 0.587, 0.114]},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Loading model with path models/6_dqn_image_default_reward_log_mlppolicy
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# /Users/dora/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 65.55GB > 3.92GB
#   warnings.warn(
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# ...
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 15 and seconds elapsed 1.0
# Logging metrics for step 30 and seconds elapsed 2.0
# Logging metrics for step 45 and seconds elapsed 3.0
# Logging metrics for step 60 and seconds elapsed 4.0
# Logging metrics for step 75 and seconds elapsed 5.0
# Logging metrics for step 90 and seconds elapsed 6.0
# Logging metrics for step 105 and seconds elapsed 7.0
# Logging metrics for step 120 and seconds elapsed 8.0
# Logging metrics for step 135 and seconds elapsed 9.0
# Logging metrics for step 150 and seconds elapsed 10.0
# Logging metrics for step 165 and seconds elapsed 11.0
# Logging metrics for step 180 and seconds elapsed 12.0
# Logging metrics for step 195 and seconds elapsed 13.0
# Logging metrics for step 210 and seconds elapsed 14.0
# Logging metrics for step 225 and seconds elapsed 15.0
# Logging metrics for step 240 and seconds elapsed 16.0
# Logging metrics for step 255 and seconds elapsed 17.0
# Logging metrics for step 270 and seconds elapsed 18.0
# Logging metrics for step 285 and seconds elapsed 19.0
# Logging metrics for step 300 and seconds elapsed 20.0
# Logging metrics for step 315 and seconds elapsed 21.0
# Logging metrics for step 330 and seconds elapsed 22.0
# Logging metrics for step 345 and seconds elapsed 23.0
# Logging metrics for step 360 and seconds elapsed 24.0
# Logging metrics for step 375 and seconds elapsed 25.0
# Logging metrics for step 390 and seconds elapsed 26.0
# Logging metrics for step 405 and seconds elapsed 27.0
# Logging metrics for step 420 and seconds elapsed 28.0
# Logging metrics for step 435 and seconds elapsed 29.0
# Logging metrics for step 450 and seconds elapsed 30.0

# %%
metrics = aggregate_and_normalize_rewards(log_filename)

if metrics:
    print("Performance metric (as percent of all steps):")
    for metric_name, avg_metric in metrics.items():
        print(f"{metric_name}: {avg_metric*100:.4f}%")
# Out:
# Performance metric (as percent of all steps):
# collision_count: 7.6377%
# right_lane_count: 76.1989%
# on_road_count: 100.0000%
# safe_distance_count: 93.9165%
# left_vehicle_overtaken_count: 8.0817%
# abrupt_accelerations_count: 31.7496%

# %% [markdown]
# # 4. Custom reward function with MlpPolicy

# %%
config_updates = {
    "safe_distance_reward": 0.1,
    "left_vehicle_overtaken_reward": -0.5,
    "collision_reward": -4,
    "smooth_driving_reward" : 0.3,
    "right_lane_reward" : 0.5, 
    "observation": {
        "type": "GrayscaleObservation",
        "observation_shape": (128, 64),
        "stack_size": 4,
        "weights": [0.2989, 0.5870, 0.1140],  # weights for RGB conversion
        "scaling": 1.75,
    },
}

# Register the custom environment
register(
    id='CustomRewardEnv',
    entry_point='HighwayEnvCustomReward:HighwayEnvFastCustomReward',
)

# %%
# Create the environment with the custom parameter
# Set log_rewards_enabled to True or False as per your requirement
log_filename="6_dqn_image_custom_reward_log_mlppolicy.csv"
log_performance_metrics_enabled=False

# %%
env = gymnasium.make("CustomRewardEnv", 
                    config=config_updates, 
                     log_performance_metrics_enabled=log_performance_metrics_enabled,
                     log_filename=log_filename
                         )
train_model(
    env=env,
    config_updates=config_updates,
    session_name='6_Group15_RLProject_dqn_custom_image_mlppolicy',
    policy="MlpPolicy"

)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'observation_shape': (128, 64),
#                  'scaling': 1.75,
#                  'stack_size': 4,
#                  'type': 'GrayscaleObservation',
#                  'weights': [0.2989, 0.587, 0.114]},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.5,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 5,
#  'smooth_driving_reward': 0.3,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Training with policy MlpPolicy
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs/tensorboard/6_Group15_RLProject_dqn_custom_image_mlppolicy_DQN/DQN_1
# /Users/dora/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 65.55GB > 4.72GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9        |
# |    ep_rew_mean      | 7.45     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 95       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 36       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 96       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 112      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.521    |
# |    n_updates        | 2        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.86     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 93       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 144      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.1      |
# |    n_updates        | 10       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 9.68     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 90       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 188      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0915   |
# |    n_updates        | 21       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.36     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 89       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 228      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0671   |
# |    n_updates        | 31       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 9.16     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 87       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 268      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 41       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.69     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 87       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 298      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0337   |
# |    n_updates        | 49       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 8.24     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 86       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 324      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0462   |
# |    n_updates        | 55       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.93     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 86       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 392      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 72       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.85     |
# |    exploration_rate | 0.795    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 86       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 431      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0298   |
# |    n_updates        | 82       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 8.51     |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 85       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 457      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 89       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 8.41     |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 85       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 492      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00656  |
# |    n_updates        | 97       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 8.39     |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 85       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 532      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0271   |
# |    n_updates        | 107      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 8.45     |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 85       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 577      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0332   |
# |    n_updates        | 119      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 8.49     |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 84       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 620      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0355   |
# |    n_updates        | 129      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.86     |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 84       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 687      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0405   |
# |    n_updates        | 146      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.78     |
# |    exploration_rate | 0.657    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 82       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 723      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 155      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.74     |
# |    exploration_rate | 0.638    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 82       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 762      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 165      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 9.15     |
# |    exploration_rate | 0.602    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 82       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 838      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0445   |
# |    n_updates        | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 9.23     |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 82       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 889      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 197      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 9.52     |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 82       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 958      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 214      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 9.62     |
# |    exploration_rate | 0.518    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 82       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 1014     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00334  |
# |    n_updates        | 228      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 9.78     |
# |    exploration_rate | 0.489    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 82       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 1075     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 9.66     |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 82       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 1110     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0391   |
# |    n_updates        | 252      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.446    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 82       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 1167     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 266      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 82       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 1240     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 284      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 9.99     |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 82       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 1304     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 300      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 82       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 1350     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 312      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.34     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 82       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 1389     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 322      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.31     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 82       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1452     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0405   |
# |    n_updates        | 337      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.284    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 82       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1507     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 351      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.267    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 81       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1543     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0423   |
# |    n_updates        | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.244    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 81       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 1592     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 372      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 81       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1660     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 389      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.181    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 81       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1725     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00317  |
# |    n_updates        | 406      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.168    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 81       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1751     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 412      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 81       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1809     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 427      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.105    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 81       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1884     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 445      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.0742   |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 81       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1949     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 462      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.0628   |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 81       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1973     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 468      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 81       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 2040     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 484      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 80       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 2131     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 80       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 2171     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 517      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 80       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 2198     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 524      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 80       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 2241     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 535      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 80       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 2280     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.042    |
# |    n_updates        | 544      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 80       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 2309     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 552      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 80       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 2347     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 561      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 80       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 2388     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0409   |
# |    n_updates        | 571      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 80       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 2436     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 583      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 80       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 2505     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0306   |
# |    n_updates        | 601      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 80       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 2564     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 615      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 80       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 2643     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0531   |
# |    n_updates        | 635      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 80       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 2721     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 655      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 80       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 2798     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 674      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 79       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 2855     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 688      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 79       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2931     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 707      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 79       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 3019     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 729      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 79       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 3071     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 742      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 79       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 3111     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 752      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 79       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 3212     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00777  |
# |    n_updates        | 777      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 79       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 3281     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 795      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 79       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 3352     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00978  |
# |    n_updates        | 812      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 79       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 3406     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 826      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 79       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 3461     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 840      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 79       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 3514     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0247   |
# |    n_updates        | 853      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 79       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 3555     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 863      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 79       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 3650     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 887      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 79       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 3724     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00365  |
# |    n_updates        | 905      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 79       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 3794     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0247   |
# |    n_updates        | 923      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 78       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 3881     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 945      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 78       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 3949     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00382  |
# |    n_updates        | 962      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 78       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 4020     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 979      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.1     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 78       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 4094     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 998      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 78       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 4116     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0289   |
# |    n_updates        | 1003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 78       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 4142     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 1010     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 78       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 4209     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 1027     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 78       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 4256     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 1038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 78       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 4304     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 1050     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.2     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 78       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 4323     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 1055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 78       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 4347     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00266  |
# |    n_updates        | 1061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 78       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 4394     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 1073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 78       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 4415     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 1078     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.9     |
# |    ep_rew_mean      | 12.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 78       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 4457     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 1089     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 78       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 4523     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00507  |
# |    n_updates        | 1105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 78       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 4595     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00871  |
# |    n_updates        | 1123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 78       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 4616     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 1128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 78       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 4706     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 1151     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.4     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 78       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 4746     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0352   |
# |    n_updates        | 4410     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 74       |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 17797    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 4424     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 74       |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 17851    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0434   |
# |    n_updates        | 4437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 74       |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 17926    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00674  |
# |    n_updates        | 4456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 74       |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 17961    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0701   |
# |    n_updates        | 4465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.4     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 74       |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 18081    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0674   |
# |    n_updates        | 4495     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.2     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 74       |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 18182    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0702   |
# |    n_updates        | 4520     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 74       |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 18257    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0327   |
# |    n_updates        | 4539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.6     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 74       |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 18307    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00841  |
# |    n_updates        | 4551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.8     |
# |    ep_rew_mean      | 15.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 74       |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 18378    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0665   |
# |    n_updates        | 4569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 74       |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 18463    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0708   |
# |    n_updates        | 4590     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.7     |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 73       |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 18517    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 4604     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 73       |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 18555    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0617   |
# |    n_updates        | 4613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 73       |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 18588    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0353   |
# |    n_updates        | 4621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 73       |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 18680    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00258  |
# |    n_updates        | 4644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 73       |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 18737    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00119  |
# |    n_updates        | 4659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 73       |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 18842    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.108    |
# |    n_updates        | 4685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.6     |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 73       |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 18882    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00169  |
# |    n_updates        | 4695     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 73       |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 18901    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0748   |
# |    n_updates        | 4700     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 73       |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 18923    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0359   |
# |    n_updates        | 4705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 14.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 73       |
# |    time_elapsed     | 257      |
# |    total_timesteps  | 19043    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0676   |
# |    n_updates        | 4735     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.2     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 73       |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 19113    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0748   |
# |    n_updates        | 4753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.3     |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 73       |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 19192    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0373   |
# |    n_updates        | 4772     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.9     |
# |    ep_rew_mean      | 15.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 73       |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 19312    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000955 |
# |    n_updates        | 4802     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17       |
# |    ep_rew_mean      | 15.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 73       |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 19413    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 4828     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.3     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 73       |
# |    time_elapsed     | 263      |
# |    total_timesteps  | 19471    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00674  |
# |    n_updates        | 4842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.7     |
# |    ep_rew_mean      | 15.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 73       |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 19567    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.072    |
# |    n_updates        | 4866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 73       |
# |    time_elapsed     | 266      |
# |    total_timesteps  | 19666    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 4891     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.2     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 73       |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 19747    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0707   |
# |    n_updates        | 4911     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.8     |
# |    ep_rew_mean      | 16.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 73       |
# |    time_elapsed     | 268      |
# |    total_timesteps  | 19837    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00393  |
# |    n_updates        | 4934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 18.1     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 73       |
# |    time_elapsed     | 269      |
# |    total_timesteps  | 19891    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 4947     |
# ----------------------------------
# Model saved to ./models/6_Group15_RLProject_dqn_custom_image_mlppolicy

# %%
log_performance_metrics_enabled=False

env = gymnasium.make('CustomRewardEnv', 
                     render_mode='rgb_array', 
                     log_performance_metrics_enabled=log_performance_metrics_enabled, 
                     log_filename=log_filename, 
                     config=config_updates
                    )
evaluate_model(
    env=env,
    config_updates={**config_updates, "simulation_frequency": 15},
    model_path='models/6_Group15_RLProject_dqn_custom_image_mlppolicy',
    algorithm='DQN',
)
# Out:
# {'action': {'type': 'DiscreteMetaAction'},
#  'centering_position': [0.3, 0.5],
#  'collision_reward': -4,
#  'controlled_vehicles': 1,
#  'duration': 30,
#  'ego_spacing': 1.5,
#  'high_speed_reward': 0.4,
#  'initial_lane_id': None,
#  'lane_change_reward': 0,
#  'lanes_count': 3,
#  'left_vehicle_overtaken_reward': -0.5,
#  'manual_control': False,
#  'normalize_reward': True,
#  'observation': {'observation_shape': (128, 64),
#                  'scaling': 1.75,
#                  'stack_size': 4,
#                  'type': 'GrayscaleObservation',
#                  'weights': [0.2989, 0.587, 0.114]},
#  'offroad_terminal': False,
#  'offscreen_rendering': False,
#  'other_vehicles_type': 'highway_env.vehicle.behavior.IDMVehicle',
#  'policy_frequency': 1,
#  'real_time_rendering': False,
#  'render_agent': True,
#  'reward_speed_range': [20, 30],
#  'right_lane_reward': 0.5,
#  'safe_distance_reward': 0.1,
#  'scaling': 5.5,
#  'screen_height': 150,
#  'screen_width': 600,
#  'show_trajectories': False,
#  'simulation_frequency': 15,
#  'smooth_driving_reward': 0.3,
#  'vehicles_count': 20,
#  'vehicles_density': 1}
# Loading model with path models/6_Group15_RLProject_dqn_custom_image_mlppolicy
# /Users/dora/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 65.55GB > 4.97GB
#   warnings.warn(

# %%
metrics = aggregate_and_normalize_rewards(log_filename)

if metrics:
    print("Performance metric (as percent of all steps):")
    for metric_name, avg_metric in metrics.items():
        print(f"{metric_name}: {avg_metric*100:.4f}%")
# Out:
# Performance metric (as percent of all steps):
# collision_count: 0.5252%
# right_lane_count: 100.0000%
# on_road_count: 100.0000%
# safe_distance_count: 99.7827%
# left_vehicle_overtaken_count: 1.1771%
# abrupt_accelerations_count: 4.0203%

# %% [markdown]
# # 5. Analysis
# Below, we compare the performances of each agent on our performance metrics, and offer an explanation for their differences.

# %% [markdown]
# | Metric                          | Default Reward (CNN) | Custom Reward (CNN) | Default Reward (MLP) | Custom Reward (MLP) |
# |---------------------------------|-----------------------|----------------------|-----------------------|----------------------|
# | collision_count                 | 7.07%                | 0.85%               | 7.64%                | 0.53%               |
# | right_lane_count                | 70.05%               | 100.00%             | 76.20%               | 100.00%             |
# | on_road_count                   | 100.00%              | 100.00%             | 100.00%              | 100.00%             |
# | safe_distance_count             | 94.74%               | 99.74%              | 93.92%               | 99.78%              |
# | left_vehicle_overtaken_count    | 8.22%                | 2.09%               | 8.08%                | 1.18%               |
# | abrupt_accelerations_count      | 30.81%               | 4.24%               | 31.75%               | 4.02%               |

# %% [markdown]
# ## Safety performance
#
# ### Collisions
# The custom reward function drastically reduces collision rates (0.85% with CNN and 0.53% with MLP) compared to the default reward function (7.07% with CNN and 7.64% with MLP).
#
# ### Right lane usage
# The custom reward function ensures that agents stay in the right lane 100% of the time, compared to lower percentages under the default reward function (70.05% for CNN and 76.20% for MLP).
#
# ### Safe distance from other vehicles:
#
# The custom reward results in higher safe distance adherence (99.74% for CNN and 99.78% for MLP) compared to the default reward function (94.74% for CNN and 93.92% for MLP).
#
# ### Overtaking left vehicles:
#
# Agents with the custom reward function overtook fewer cars on the left, as intended by the design (2.09% for CNN and 1.18% for MLP vs. 8.22% for CNN and 8.08% for MLP under the default).
#
# ### Comfortable acceleration:
# The custom reward also reduced abrupt accelerations significantly (4.24% for CNN and 4.02% for MLP vs. 30.81% for CNN and 31.75% for MLP under the default).

# %% [markdown]
# Using a custom reward function with both CNN and MLP policies significantly improves performance metrics associated with safety and adherence to our performance metrics. However, the CNN and MLP policies were nearly equal on our metrics, which was unexpected, given that MLP policies are not intended to process image data.
#
# Staying out of the right lane or maintaining a safe distance likely correspond to easily distinguishable grayscale patterns (e.g., lane markings, proximity to other vehicles). MLP policies would probably pick up these patterns in the flattened image vector, even without understanding their spatial arrangement.
#
# It is possible that our simple environment allows the two policies to have comparable performance, but that increasing the number of vehicles or lanes may cause agents trained with an MLP policy to perform worse than ones trained with a CNN policy. The fact that CNNs process spatial relationships and patterns from images would make them inherently scalable to more complex environments.
